# %%
# =============================================================================
# CELL 1: Setup and Directory Structure
# =============================================================================

import sys
from pathlib import Path

# Setup paths
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Configuration helper
def create_config(overrides=None):
    from config import PipelineConfig
    config = PipelineConfig(overrides)
    config.project_root = project_root
    config.documents_root = project_root / "documents"
    config.literature_folder = config.documents_root / "literature"
    config.your_work_folder = config.documents_root / "your_work"
    config.biblio_folder = config.documents_root / "biblio"
    config.current_drafts_folder = config.documents_root / "current_drafts"
    config.cache_file = project_root / "physics_knowledge_base.pkl"
    config._create_directories()
    return config

# Create configuration and directories
config = create_config()

print("📁 YOUR PHYSICS PIPELINE DIRECTORY STRUCTURE")
print("=" * 60)
print(f"Project Root: {project_root}")
print()

# Show where to put files
folders = {
    "biblio": "Put your Zotero .bib files here",
    "literature": "Downloaded papers go here (auto-created)",
    "your_work": "Your own published papers",
    "current_drafts": "Your current drafts"
}

for folder_name, description in folders.items():
    folder_path = config.documents_root / folder_name
    exists = "✅" if folder_path.exists() else "❌"
    file_count = len(list(folder_path.iterdir())) if folder_path.exists() else 0
    
    print(f"{exists} {folder_name}/ - {description}")
    print(f"   📍 Location: {folder_path}")
    print(f"   📊 Current files: {file_count}")
    print()

print("🎯 TO GET STARTED:")
print("1. Export .bib files from Zotero → Save to documents/biblio/")
print("2. Copy your papers → Save to documents/your_work/")
print("3. Run the commands below!")
# Out:
# 📁 YOUR PHYSICS PIPELINE DIRECTORY STRUCTURE
# ============================================================
# Project Root: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis
#
# ✅ biblio/ - Put your Zotero .bib files here
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio
#    📊 Current files: 2
#
# ✅ literature/ - Downloaded papers go here (auto-created)
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
#    📊 Current files: 257
#
# ✅ your_work/ - Your own published papers
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/your_work
#    📊 Current files: 10
#
# ✅ current_drafts/ - Your current drafts
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/current_drafts
#    📊 Current files: 2
#
# 🎯 TO GET STARTED:
# 1. Export .bib files from Zotero → Save to documents/biblio/
# 2. Copy your papers → Save to documents/your_work/
# 3. Run the commands below!

# %%
# =============================================================================
# CELL 2: Check for Existing .bib Files
# =============================================================================

# Check what .bib files you already have
biblio_folder = config.biblio_folder
bib_files = list(biblio_folder.glob("*.bib"))

print("📚 CHECKING FOR EXISTING .BIB FILES")
print("=" * 40)

if bib_files:
    print(f"✅ Found {len(bib_files)} .bib file(s):")
    for bib_file in bib_files:
        file_size = bib_file.stat().st_size / 1024  # KB
        print(f"   📄 {bib_file.name} ({file_size:.1f} KB)")
    
    # Quick preview of first .bib file
    first_bib = bib_files[0]
    try:
        content = first_bib.read_text()
        lines = content.split('\n')[:10]
        print(f"\n📖 Preview of {first_bib.name}:")
        for line in lines:
            if line.strip():
                print(f"   {line[:60]}...")
                break
    except Exception as e:
        print(f"   Could not preview file: {e}")
        
    print(f"\n🚀 Ready to download literature!")
    
else:
    print("📭 No .bib files found")
    print("\n💡 TO ADD .BIB FILES:")
    print("1. Open Zotero")
    print("2. Select your collection")  
    print("3. Right-click → Export Collection")
    print("4. Choose 'BibTeX' format")
    print(f"5. Save to: {biblio_folder}")
# Out:
# 📚 CHECKING FOR EXISTING .BIB FILES
# ========================================
# ✅ Found 1 .bib file(s):
#    📄 DynamicsConditionalEnsembles_small.bib (172.7 KB)
#
# 📖 Preview of DynamicsConditionalEnsembles_small.bib:
#    @article{AbhinavDeshpande2022TightBoundsConvergence,...
#
# 🚀 Ready to download literature!

# %%
# =============================================================================
# CELL 3: Download Literature from .bib Files (IF YOU HAVE THEM)
# =============================================================================

# Only run this if you have .bib files
bib_files = list(config.biblio_folder.glob("*.bib"))

if bib_files:
    print("🚀 DOWNLOADING LITERATURE FROM ARXIV")
    print("=" * 45)
    
    from src.downloaders import LiteratureDownloader
    
    # Use the first .bib file (or modify to use a specific one)
    bib_file = bib_files[0]
    print(f"📖 Using: {bib_file.name}")
    
    # Initialize downloader
    downloader = LiteratureDownloader(
        output_directory=config.literature_folder,
        delay_between_downloads=config.download_delay,
        arxiv_config=config.get_arxiv_config()
    )
    
    print("⏳ Starting download... (this may take several minutes)")
    print("💡 The system will:")
    print("   1. Parse your .bib file")
    print("   2. Search for papers on arXiv")
    print("   3. Download PDFs and TEX files")
    print("   4. Generate a detailed report")
    print()
    
    # Download papers
    results = downloader.download_from_bibtex(bib_file)
    
    print(f"\n✅ DOWNLOAD COMPLETE!")
    print(f"   📥 Successfully downloaded: {len(results['successful'])}")
    print(f"   ❌ Not found: {len(results['failed'])}")
    
    if results['successful']:
        print(f"\n📄 Sample downloads:")
        for i, result in enumerate(results['successful'][:3]):
            paper = result.paper_metadata
            print(f"   {i+1}. {paper.title[:50]}...")
            print(f"      arXiv: {result.search_result.arxiv_id}")
            
else:
    print("⏭️ SKIPPING DOWNLOAD - No .bib files found")
    print("Add .bib files to documents/biblio/ first!")
# Out:
# 🚀 DOWNLOADING LITERATURE FROM ARXIV
# =============================================
# 📖 Using: DynamicsConditionalEnsembles_small.bib
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.bibtex_parser - INFO - BibTeX parser initialized
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - ArXiv searcher initialized
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - Literature downloader initialized with output: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
# ⏳ Starting download... (this may take several minutes)
# 💡 The system will:
#    1. Parse your .bib file
#    2. Search for papers on arXiv
#    3. Download PDFs and TEX files
#    4. Generate a detailed report
#
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - Starting download process from /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.bibtex_parser - INFO - Parsing BibTeX file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.bibtex_parser - INFO - Successfully parsed 116 papers from /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.bibtex_parser - INFO - Skipped 2 book entries
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - Found 116 papers to process
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 1/116: Tight Bounds on the Convergence of Noisy Random Ci...
# 2025-06-02 14:45:09 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Tight Bounds on the Convergence of Noisy Random Ci...
# 2025-06-02 14:45:11 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2112.00716
# 2025-06-02 14:45:11 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.pdf
# 2025-06-02 14:45:11 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.tex
# 2025-06-02 14:45:11 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.tex
# 2025-06-02 14:45:12 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2112.00716
# 2025-06-02 14:45:12 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 2/116: Critical Properties of the Measurement-Induced Tra...
# 2025-06-02 14:45:12 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Critical Properties of the Measurement-Induced Tra...
# 2025-06-02 14:45:14 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1911.00008
# 2025-06-02 14:45:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.pdf
# 2025-06-02 14:45:15 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 2025-06-02 14:45:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 2025-06-02 14:45:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1911.00008
# 2025-06-02 14:45:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 3/116: Exponential Shortcut to Measurement-Induced Entang...
# 2025-06-02 14:45:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Exponential Shortcut to Measurement-Induced Entang...
# 2025-06-02 14:45:18 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2302.14044
# 2025-06-02 14:45:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.pdf
# 2025-06-02 14:45:19 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.tex
# 2025-06-02 14:45:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.tex
# 2025-06-02 14:45:20 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2302.14044
# 2025-06-02 14:45:20 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 4/116: Measurement-Induced Topological Entanglement Trans...
# 2025-06-02 14:45:20 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Induced Topological Entanglement Trans...
# 2025-06-02 14:45:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2004.07243
# 2025-06-02 14:45:23 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.07243.pdf
# 2025-06-02 14:45:23 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.07243.tex
# 2025-06-02 14:45:23 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.07243.tex
# 2025-06-02 14:45:24 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2004.07243
# 2025-06-02 14:45:24 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 5/116: Fluctuations of Work from Quantum Subensembles: Th...
# 2025-06-02 14:45:24 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Fluctuations of Work from Quantum Subensembles: Th...
# 2025-06-02 14:45:28 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Fluctuations of Work from Quantum Subensembles: Th...
# 2025-06-02 14:45:28 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 6/116: Unitary-Projective Entanglement Dynamics...
# 2025-06-02 14:45:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Unitary-Projective Entanglement Dynamics...
# 2025-06-02 14:45:30 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1808.05949
# 2025-06-02 14:45:30 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05949.pdf
# 2025-06-02 14:45:30 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05949.tex
# 2025-06-02 14:45:30 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05949.tex
# 2025-06-02 14:45:31 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1808.05949
# 2025-06-02 14:45:31 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 7/116: Many-Body Quantum Chaos and Space-time Translation...
# 2025-06-02 14:45:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Many-Body Quantum Chaos and Space-time Translation...
# 2025-06-02 14:45:33 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2109.04475
# 2025-06-02 14:45:34 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.04475.pdf
# 2025-06-02 14:45:34 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.04475.tex
# 2025-06-02 14:45:34 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.04475.tex
# 2025-06-02 14:45:35 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2109.04475
# 2025-06-02 14:45:35 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 8/116: Geometry of Quantum Evolution...
# 2025-06-02 14:45:35 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Geometry of Quantum Evolution...
# 2025-06-02 14:45:41 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Geometry of Quantum Evolution...
# 2025-06-02 14:45:41 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 9/116: Triorthogonal Uniqueness Theorem and Its Relevance...
# 2025-06-02 14:45:41 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Triorthogonal Uniqueness Theorem and Its Relevance...
# 2025-06-02 14:45:45 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Triorthogonal Uniqueness Theorem and Its Relevance...
# 2025-06-02 14:45:45 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 10/116: Quantum T-Designs: T-Wise Independence in the Quan...
# 2025-06-02 14:45:45 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Quantum T-Designs: T-Wise Independence in the Quan...
# 2025-06-02 14:45:49 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Quantum T-Designs: T-Wise Independence in the Quan...
# 2025-06-02 14:45:49 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 11/116: No-Faster-than-Light-Signaling Implies Linear Evol...
# 2025-06-02 14:45:49 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: No-Faster-than-Light-Signaling Implies Linear Evol...
# 2025-06-02 14:45:50 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1411.1768
# 2025-06-02 14:45:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
# 2025-06-02 14:45:51 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 14:45:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 14:45:52 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1411.1768
# 2025-06-02 14:45:52 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 12/116: Entanglement Transitions and Quantum Bifurcations ...
# 2025-06-02 14:45:52 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Transitions and Quantum Bifurcations ...
# 2025-06-02 14:45:53 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2307.05685
# 2025-06-02 14:45:53 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.pdf
# 2025-06-02 14:45:54 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.tex
# 2025-06-02 14:45:54 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.tex
# 2025-06-02 14:45:55 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2307.05685
# 2025-06-02 14:45:55 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 13/116: Quantum Discord and Its Allies: A Review of Recent...
# 2025-06-02 14:45:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Quantum Discord and Its Allies: A Review of Recent...
# 2025-06-02 14:45:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1703.10542
# 2025-06-02 14:45:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1703.10542.pdf
# 2025-06-02 14:46:00 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1703.10542.tex
# 2025-06-02 14:46:00 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1703.10542.tex
# 2025-06-02 14:46:01 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1703.10542
# 2025-06-02 14:46:01 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 14/116: Random Quantum Circuits Are Approximate 2-Designs...
# 2025-06-02 14:46:01 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Random Quantum Circuits Are Approximate 2-Designs...
# 2025-06-02 14:46:04 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 0802.1919
# 2025-06-02 14:46:05 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0802.1919.pdf
# 2025-06-02 14:46:05 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0802.1919.tex
# 2025-06-02 14:46:05 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0802.1919.tex
# 2025-06-02 14:46:06 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 0802.1919
# 2025-06-02 14:46:06 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 15/116: Conditional Entropy and Data Processing: An Axioma...
# 2025-06-02 14:46:06 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Conditional Entropy and Data Processing: An Axioma...
# 2025-06-02 14:46:10 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Conditional Entropy and Data Processing: An Axioma...
# 2025-06-02 14:46:10 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 16/116: Impossibility of Distinguishing Two Preparations f...
# 2025-06-02 14:46:10 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Impossibility of Distinguishing Two Preparations f...
# 2025-06-02 14:46:14 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1904.05722
# 2025-06-02 14:46:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1904.05722.pdf
# 2025-06-02 14:46:15 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1904.05722.tar.gz: invalid header
# 2025-06-02 14:46:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1904.05722
# 2025-06-02 14:46:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 17/116: Separability Criterion for Density Matrices....
# 2025-06-02 14:46:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Separability Criterion for Density Matrices....
# 2025-06-02 14:46:21 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Separability Criterion for Density Matrices....
# 2025-06-02 14:46:21 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 18/116: Geometry of Quantum Mechanics...
# 2025-06-02 14:46:21 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Geometry of Quantum Mechanics...
# 2025-06-02 14:46:25 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Geometry of Quantum Mechanics...
# 2025-06-02 14:46:25 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 19/116: Geometrical Formulation of Quantum Mechanics...
# 2025-06-02 14:46:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Geometrical Formulation of Quantum Mechanics...
# 2025-06-02 14:46:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1405.7693
# 2025-06-02 14:46:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1405.7693.pdf
# 2025-06-02 14:46:28 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1405.7693.tar.gz: not a gzip file
# 2025-06-02 14:46:29 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1405.7693
# 2025-06-02 14:46:29 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 20/116: An Elementary Introduction to the Geometry of Quan...
# 2025-06-02 14:46:29 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: An Elementary Introduction to the Geometry of Quan...
# 2025-06-02 14:46:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1901.06688
# 2025-06-02 14:46:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1901.06688.pdf
# 2025-06-02 14:46:31 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1901.06688.tex
# 2025-06-02 14:46:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1901.06688.tex
# 2025-06-02 14:46:32 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1901.06688
# 2025-06-02 14:46:32 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 21/116: Stochastic Differential Equations and a Posteriori...
# 2025-06-02 14:46:32 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Stochastic Differential Equations and a Posteriori...
# 2025-06-02 14:46:36 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Stochastic Differential Equations and a Posteriori...
# 2025-06-02 14:46:36 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 22/116: No-Faster-than-Light-Signaling Implies Linear Evol...
# 2025-06-02 14:46:36 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: No-Faster-than-Light-Signaling Implies Linear Evol...
# 2025-06-02 14:46:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1411.1768
# 2025-06-02 14:46:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
# 2025-06-02 14:46:37 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 14:46:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 14:46:39 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1411.1768
# 2025-06-02 14:46:39 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 23/116: Numerical Evaluation of Convex-Roof Entanglement M...
# 2025-06-02 14:46:39 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Numerical Evaluation of Convex-Roof Entanglement M...
# 2025-06-02 14:46:40 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 0905.3106
# 2025-06-02 14:46:40 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.pdf
# 2025-06-02 14:46:41 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.tex
# 2025-06-02 14:46:41 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.tex
# 2025-06-02 14:46:42 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 0905.3106
# 2025-06-02 14:46:42 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 24/116: Postselection-Free Entanglement Dynamics via Space...
# 2025-06-02 14:46:42 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Postselection-Free Entanglement Dynamics via Space...
# 2025-06-02 14:46:44 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2010.15840
# 2025-06-02 14:46:44 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.pdf
# 2025-06-02 14:46:45 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.tex
# 2025-06-02 14:46:45 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.tex
# 2025-06-02 14:46:46 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2010.15840
# 2025-06-02 14:46:46 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 25/116: Entanglement Phase Transitions in Measurement-Only...
# 2025-06-02 14:46:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Phase Transitions in Measurement-Only...
# 2025-06-02 14:46:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2004.09560
# 2025-06-02 14:46:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.pdf
# 2025-06-02 14:46:48 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.tex
# 2025-06-02 14:46:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.tex
# 2025-06-02 14:46:49 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2004.09560
# 2025-06-02 14:46:49 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 26/116: Dynamical Purification and the Emergence of Quantu...
# 2025-06-02 14:46:49 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Dynamical Purification and the Emergence of Quantu...
# 2025-06-02 14:46:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2204.13657
# 2025-06-02 14:46:52 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.pdf
# 2025-06-02 14:46:53 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 2025-06-02 14:46:53 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 2025-06-02 14:46:54 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2204.13657
# 2025-06-02 14:46:54 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 27/116: Solvable Model of Deep Thermalization with Distinc...
# 2025-06-02 14:46:54 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Solvable Model of Deep Thermalization with Distinc...
# 2025-06-02 14:46:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2208.10542
# 2025-06-02 14:46:56 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.pdf
# 2025-06-02 14:46:56 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.tex
# 2025-06-02 14:46:56 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.tex
# 2025-06-02 14:46:57 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2208.10542
# 2025-06-02 14:46:57 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 28/116: Dynamical Purification and the Emergence of Quantu...
# 2025-06-02 14:46:57 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Dynamical Purification and the Emergence of Quantu...
# 2025-06-02 14:46:59 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2204.13657
# 2025-06-02 14:47:00 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.pdf
# 2025-06-02 14:47:00 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 2025-06-02 14:47:00 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 2025-06-02 14:47:02 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2204.13657
# 2025-06-02 14:47:02 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 29/116: Random Quantum Circuits...
# 2025-06-02 14:47:02 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Random Quantum Circuits...
# 2025-06-02 14:47:03 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2207.14280
# 2025-06-02 14:47:03 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2207.14280.pdf
# 2025-06-02 14:47:05 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2207.14280.tex
# 2025-06-02 14:47:05 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2207.14280.tex
# 2025-06-02 14:47:06 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2207.14280
# 2025-06-02 14:47:06 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 30/116: Classicality, the Ensemble Interpretation, and Dec...
# 2025-06-02 14:47:06 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Classicality, the Ensemble Interpretation, and Dec...
# 2025-06-02 14:47:10 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Classicality, the Ensemble Interpretation, and Dec...
# 2025-06-02 14:47:10 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 31/116: Measurement-Induced Transition in Long-Range Inter...
# 2025-06-02 14:47:10 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Induced Transition in Long-Range Inter...
# 2025-06-02 14:47:11 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2104.13372
# 2025-06-02 14:47:13 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.pdf
# 2025-06-02 14:47:13 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.tex
# 2025-06-02 14:47:13 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.tex
# 2025-06-02 14:47:14 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2104.13372
# 2025-06-02 14:47:14 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 32/116: What Is Quantum Mechanics Trying to Tell Us...
# 2025-06-02 14:47:14 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: What Is Quantum Mechanics Trying to Tell Us...
# 2025-06-02 14:47:18 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: What Is Quantum Mechanics Trying to Tell Us...
# 2025-06-02 14:47:18 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 33/116: A Classical Analog for Electronic Degrees of Freed...
# 2025-06-02 14:47:18 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: A Classical Analog for Electronic Degrees of Freed...
# 2025-06-02 14:47:22 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: A Classical Analog for Electronic Degrees of Freed...
# 2025-06-02 14:47:22 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 34/116: Properties of Quantum Trajectories for Counting Me...
# 2025-06-02 14:47:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Properties of Quantum Trajectories for Counting Me...
# 2025-06-02 14:47:27 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Properties of Quantum Trajectories for Counting Me...
# 2025-06-02 14:47:27 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 35/116: Probability Distributions Consistent with a Mixed ...
# 2025-06-02 14:47:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Probability Distributions Consistent with a Mixed ...
# 2025-06-02 14:47:30 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Probability Distributions Consistent with a Mixed ...
# 2025-06-02 14:47:30 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 36/116: Characterizing Mixing and Measurement in Quantum M...
# 2025-06-02 14:47:30 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Characterizing Mixing and Measurement in Quantum M...
# 2025-06-02 14:47:34 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Characterizing Mixing and Measurement in Quantum M...
# 2025-06-02 14:47:34 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 37/116: Effective Theory for the Measurement-Induced Phase...
# 2025-06-02 14:47:34 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Effective Theory for the Measurement-Induced Phase...
# 2025-06-02 14:47:36 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2102.08381
# 2025-06-02 14:47:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2102.08381.pdf
# 2025-06-02 14:47:37 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2102.08381.tex
# 2025-06-02 14:47:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2102.08381.tex
# 2025-06-02 14:47:38 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2102.08381
# 2025-06-02 14:47:38 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 38/116: Dynamical Purification Phase Transition Induced by...
# 2025-06-02 14:47:38 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Dynamical Purification Phase Transition Induced by...
# 2025-06-02 14:47:42 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Dynamical Purification Phase Transition Induced by...
# 2025-06-02 14:47:42 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 39/116: Geometry of Quantum States...
# 2025-06-02 14:47:42 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Geometry of Quantum States...
# 2025-06-02 14:47:46 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Geometry of Quantum States...
# 2025-06-02 14:47:46 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 40/116: Entanglement Transition in the Projective Transver...
# 2025-06-02 14:47:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Transition in the Projective Transver...
# 2025-06-02 14:47:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2006.09748
# 2025-06-02 14:47:49 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2006.09748.pdf
# 2025-06-02 14:47:49 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2006.09748.tex
# 2025-06-02 14:47:49 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2006.09748.tex
# 2025-06-02 14:47:50 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2006.09748
# 2025-06-02 14:47:50 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 41/116: Stochastic Quantum Dynamics and Relativity...
# 2025-06-02 14:47:50 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Stochastic Quantum Dynamics and Relativity...
# 2025-06-02 14:47:54 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Stochastic Quantum Dynamics and Relativity...
# 2025-06-02 14:47:54 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 42/116: The Quantum-State Diffusion Model Applied to Open ...
# 2025-06-02 14:47:54 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: The Quantum-State Diffusion Model Applied to Open ...
# 2025-06-02 14:47:57 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: The Quantum-State Diffusion Model Applied to Open ...
# 2025-06-02 14:47:57 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 43/116: Properties of Mixtures on Non-Orthogonal States...
# 2025-06-02 14:47:57 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Properties of Mixtures on Non-Orthogonal States...
# 2025-06-02 14:48:02 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Properties of Mixtures on Non-Orthogonal States...
# 2025-06-02 14:48:02 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 44/116: Negative Entropy and Information in Quantum Mechan...
# 2025-06-02 14:48:02 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Negative Entropy and Information in Quantum Mechan...
# 2025-06-02 14:48:06 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Negative Entropy and Information in Quantum Mechan...
# 2025-06-02 14:48:06 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 45/116: Hamiltonian Formulation of Statistical Ensembles a...
# 2025-06-02 14:48:06 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Hamiltonian Formulation of Statistical Ensembles a...
# 2025-06-02 14:48:13 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Hamiltonian Formulation of Statistical Ensembles a...
# 2025-06-02 14:48:13 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 46/116: Properties of Subentropy...
# 2025-06-02 14:48:13 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Properties of Subentropy...
# 2025-06-02 14:48:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1310.1312
# 2025-06-02 14:48:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1310.1312.pdf
# 2025-06-02 14:48:15 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1310.1312.tar.gz: invalid header
# 2025-06-02 14:48:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1310.1312
# 2025-06-02 14:48:16 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 47/116: Classical Models of Entanglement in Monitored Rand...
# 2025-06-02 14:48:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Classical Models of Entanglement in Monitored Rand...
# 2025-06-02 14:48:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2004.06736
# 2025-06-02 14:48:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.06736.pdf
# 2025-06-02 14:48:19 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.06736.tex
# 2025-06-02 14:48:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.06736.tex
# 2025-06-02 14:48:21 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2004.06736
# 2025-06-02 14:48:21 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 48/116: Anharmonic Quantum Mechanical Systems Do Not Featu...
# 2025-06-02 14:48:21 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Anharmonic Quantum Mechanical Systems Do Not Featu...
# 2025-06-02 14:48:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1611.03303
# 2025-06-02 14:48:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1611.03303.pdf
# 2025-06-02 14:48:23 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1611.03303.tex
# 2025-06-02 14:48:23 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1611.03303.tex
# 2025-06-02 14:48:24 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1611.03303
# 2025-06-02 14:48:24 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 49/116: Measurement-Induced Entanglement Transitions in Ma...
# 2025-06-02 14:48:24 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Induced Entanglement Transitions in Ma...
# 2025-06-02 14:48:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2005.13603
# 2025-06-02 14:48:26 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.13603.pdf
# 2025-06-02 14:48:26 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.13603.tex
# 2025-06-02 14:48:26 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.13603.tex
# 2025-06-02 14:48:28 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2005.13603
# 2025-06-02 14:48:28 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 50/116: Measurement-Induced Criticality and Entanglement C...
# 2025-06-02 14:48:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Induced Criticality and Entanglement C...
# 2025-06-02 14:48:32 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Measurement-Induced Criticality and Entanglement C...
# 2025-06-02 14:48:32 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 51/116: Entanglement Transition in a Monitored Free-Fermio...
# 2025-06-02 14:48:32 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Transition in a Monitored Free-Fermio...
# 2025-06-02 14:48:36 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Entanglement Transition in a Monitored Free-Fermio...
# 2025-06-02 14:48:36 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 52/116: Universal Behavior beyond Multifractality of Wave ...
# 2025-06-02 14:48:36 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Universal Behavior beyond Multifractality of Wave ...
# 2025-06-02 14:48:38 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2109.06882
# 2025-06-02 14:48:39 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.06882.pdf
# 2025-06-02 14:48:40 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.06882.tex
# 2025-06-02 14:48:40 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.06882.tex
# 2025-06-02 14:48:42 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2109.06882
# 2025-06-02 14:48:42 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 53/116: Geometrical Description of Berry's Phase...
# 2025-06-02 14:48:42 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Geometrical Description of Berry's Phase...
# 2025-06-02 14:48:46 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Geometrical Description of Berry's Phase...
# 2025-06-02 14:48:46 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 54/116: 'Lazy' Quantum Ensembles...
# 2025-06-02 14:48:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: 'Lazy' Quantum Ensembles...
# 2025-06-02 14:48:50 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: 'Lazy' Quantum Ensembles...
# 2025-06-02 14:48:50 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 55/116: A Geometric Hamiltonian Description of Composite Q...
# 2025-06-02 14:48:50 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: A Geometric Hamiltonian Description of Composite Q...
# 2025-06-02 14:48:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1408.1839
# 2025-06-02 14:48:52 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1408.1839.pdf
# ...
# 2025-06-02 14:52:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2105.08076.tex
# 2025-06-02 14:52:29 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2105.08076
# 2025-06-02 14:52:29 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 104/116: Decoherence and Relaxation of a Superconducting Qu...
# 2025-06-02 14:52:29 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Decoherence and Relaxation of a Superconducting Qu...
# 2025-06-02 14:52:33 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Decoherence and Relaxation of a Superconducting Qu...
# 2025-06-02 14:52:33 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 105/116: Emergent Statistical Mechanics of Entanglement in ...
# 2025-06-02 14:52:33 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Emergent Statistical Mechanics of Entanglement in ...
# 2025-06-02 14:52:34 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1804.09737
# 2025-06-02 14:52:35 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1804.09737.pdf
# 2025-06-02 14:52:35 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1804.09737.tex
# 2025-06-02 14:52:35 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1804.09737.tex
# 2025-06-02 14:52:36 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1804.09737
# 2025-06-02 14:52:36 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 106/116: The Entanglement Membrane in Chaotic Many-Body Sys...
# 2025-06-02 14:52:36 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: The Entanglement Membrane in Chaotic Many-Body Sys...
# 2025-06-02 14:52:39 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1912.12311
# 2025-06-02 14:52:39 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1912.12311.pdf
# 2025-06-02 14:52:40 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1912.12311.tex
# 2025-06-02 14:52:40 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1912.12311.tex
# 2025-06-02 14:52:41 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1912.12311
# 2025-06-02 14:52:41 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 107/116: Exact Emergent Quantum State Designs from Quantum ...
# 2025-06-02 14:52:41 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Exact Emergent Quantum State Designs from Quantum ...
# 2025-06-02 14:52:42 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2109.07491
# 2025-06-02 14:52:43 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.07491.pdf
# 2025-06-02 14:52:43 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.07491.tex
# 2025-06-02 14:52:43 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2109.07491.tex
# 2025-06-02 14:52:44 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2109.07491
# 2025-06-02 14:52:44 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 108/116: On the Quantum Correction For Thermodynamic Equili...
# 2025-06-02 14:52:44 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: On the Quantum Correction For Thermodynamic Equili...
# 2025-06-02 14:52:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1505.07760
# 2025-06-02 14:52:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1505.07760.pdf
# 2025-06-02 14:52:47 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1505.07760.tex
# 2025-06-02 14:52:47 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1505.07760.tex
# 2025-06-02 14:52:48 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1505.07760
# 2025-06-02 14:52:48 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 109/116: A Single Quantum Cannot Be Cloned...
# 2025-06-02 14:52:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: A Single Quantum Cannot Be Cloned...
# 2025-06-02 14:52:52 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: A Single Quantum Cannot Be Cloned...
# 2025-06-02 14:52:52 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 110/116: A Classical Interpretation of the Scrooge Distribu...
# 2025-06-02 14:52:52 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: A Classical Interpretation of the Scrooge Distribu...
# 2025-06-02 14:52:54 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1808.05179
# 2025-06-02 14:52:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05179.pdf
# 2025-06-02 14:52:55 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05179.tex
# 2025-06-02 14:52:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1808.05179.tex
# 2025-06-02 14:52:56 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1808.05179
# 2025-06-02 14:52:56 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 111/116: Theory of the Phase Transition in Random Unitary C...
# 2025-06-02 14:52:56 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Theory of the Phase Transition in Random Unitary C...
# 2025-06-02 14:52:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1908.04305
# 2025-06-02 14:52:59 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1908.04305.pdf
# 2025-06-02 14:52:59 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1908.04305.tex
# 2025-06-02 14:52:59 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1908.04305.tex
# 2025-06-02 14:53:01 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1908.04305
# 2025-06-02 14:53:01 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 112/116: Purification and Scrambling in a Chaotic Hamiltoni...
# 2025-06-02 14:53:01 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Purification and Scrambling in a Chaotic Hamiltoni...
# 2025-06-02 14:53:02 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2209.08897
# 2025-06-02 14:53:03 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2209.08897.pdf
# 2025-06-02 14:53:03 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2209.08897.tex
# 2025-06-02 14:53:03 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2209.08897.tex
# 2025-06-02 14:53:04 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2209.08897
# 2025-06-02 14:53:04 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 113/116: Continuous Gaussian Measurements of the Free Boson...
# 2025-06-02 14:53:04 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Continuous Gaussian Measurements of the Free Boson...
# 2025-06-02 14:53:06 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2108.04256
# 2025-06-02 14:53:07 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.pdf
# 2025-06-02 14:53:07 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.tex
# 2025-06-02 14:53:07 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.tex
# 2025-06-02 14:53:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2108.04256
# 2025-06-02 14:53:09 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 114/116: Continuous Gaussian Measurements of the Free Boson...
# 2025-06-02 14:53:09 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Continuous Gaussian Measurements of the Free Boson...
# 2025-06-02 14:53:12 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2108.04256
# 2025-06-02 14:53:12 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.pdf
# 2025-06-02 14:53:13 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.tex
# 2025-06-02 14:53:13 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2108.04256.tex
# 2025-06-02 14:53:14 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 2108.04256
# 2025-06-02 14:53:14 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 115/116: Critical Properties of the Measurement-Induced Tra...
# 2025-06-02 14:53:14 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Critical Properties of the Measurement-Induced Tra...
# 2025-06-02 14:53:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1911.00008
# 2025-06-02 14:53:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.pdf
# 2025-06-02 14:53:16 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 2025-06-02 14:53:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 2025-06-02 14:53:18 - physics_pipeline.src.downloaders.literature_downloader - INFO - ✓ Successfully downloaded: 1911.00008
# 2025-06-02 14:53:18 - physics_pipeline.src.downloaders.literature_downloader - INFO - Processing paper 116/116: Contractive Freedoms of Ensembles and Quantum Chan...
# 2025-06-02 14:53:18 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Contractive Freedoms of Ensembles and Quantum Chan...
# 2025-06-02 14:53:25 - physics_pipeline.src.downloaders.literature_downloader - WARNING - ✗ Failed to download: Contractive Freedoms of Ensembles and Quantum Chan...
# 2025-06-02 14:53:25 - physics_pipeline.src.downloaders.literature_downloader - INFO - Download report saved to /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/download_report.md
#
# ================================================================================
# 📚 LITERATURE DOWNLOAD SUMMARY
# ================================================================================
#
# 📊 OVERALL STATISTICS:
#    Total papers processed: 116
#    Successfully downloaded: 79
#    Failed downloads: 37
#    Success rate: 68.1%
#    Total time: 496.3 seconds
#    Average time per paper: 4.3 seconds
#
# 📄 FILE DOWNLOADS:
#    PDF files: 79
#    TEX files: 70
#
# 🔍 SEARCH METHODS:
#    title_high_confidence: 64 papers
#    title_with_abstract_validation: 2 papers
#    google_search: 11 papers
#    abstract_search: 2 papers
#
# ✅ SUCCESSFUL DOWNLOADS (showing first 5):
#    1. Tight Bounds on the Convergence of Noisy Random Circuits to ...
#       arXiv: 2112.00716 (confidence: 1.000)
#    2. Critical Properties of the Measurement-Induced Transition in...
#       arXiv: 1911.00008 (confidence: 1.000)
#    3. Exponential Shortcut to Measurement-Induced Entanglement Pha...
#       arXiv: 2302.14044 (confidence: 1.000)
#    4. Measurement-Induced Topological Entanglement Transitions in ...
#       arXiv: 2004.07243 (confidence: 1.000)
#    5. Unitary-Projective Entanglement Dynamics...
#       arXiv: 1808.05949 (confidence: 1.000)
#
# ❌ FAILED DOWNLOADS (showing first 3):
#    1. Fluctuations of Work from Quantum Subensembles: The Case aga...
#       Reason: Not found using any search method
#    2. Geometry of Quantum Evolution...
#       Reason: Not found using any search method
#    3. Triorthogonal Uniqueness Theorem and Its Relevance to the In...
#       Reason: Not found using any search method
#
# 🌐 API USAGE:
#    ArXiv API calls: 164
#    Google searches: 48
# ================================================================================
#
# ✅ DOWNLOAD COMPLETE!
#    📥 Successfully downloaded: 79
#    ❌ Not found: 37
#
# 📄 Sample downloads:
#    1. Tight Bounds on the Convergence of Noisy Random Ci...
#       arXiv: 2112.00716
#    2. Critical Properties of the Measurement-Induced Tra...
#       arXiv: 1911.00008
#    3. Exponential Shortcut to Measurement-Induced Entang...
#       arXiv: 2302.14044

# %%
# =============================================================================
# CELL 4: Build Knowledge Base (WITH PYTORCH FIX)
# =============================================================================

# PYTORCH COMPATIBILITY FIX - Add this first!
import torch

if not hasattr(torch, 'get_default_device'):
    def get_default_device():
        """Fallback implementation for older PyTorch versions."""
        if torch.cuda.is_available():
            return torch.device('cuda')
        else:
            return torch.device('cpu')
    
    torch.get_default_device = get_default_device
    print("✅ Applied PyTorch compatibility fix")

# Now the imports should work
print("\n🏗️ BUILDING KNOWLEDGE BASE")
print("=" * 35)

from src.core import KnowledgeBase

# Initialize knowledge base
kb = KnowledgeBase(
    embedding_model=config.embedding_model,
    chunk_size=config.chunk_size,
    chunk_overlap=config.chunk_overlap
)

print("⏳ Building knowledge base from all documents...")
print("💡 This processes:")
print("   📚 Downloaded literature")
print("   📝 Your own papers") 
print("   ✏️  Current drafts")
print("   🧠 Creates semantic embeddings")
print()

# Build knowledge base
stats = kb.build_from_directories(
    literature_folder=config.literature_folder,
    your_work_folder=config.your_work_folder,
    current_drafts_folder=config.current_drafts_folder
)

print("✅ KNOWLEDGE BASE BUILT!")
print(f"   📚 Total documents: {stats.get('total_documents', 0)}")
print(f"   ✅ Successfully processed: {stats.get('successful_documents', 0)}")
print(f"   🧩 Total text chunks: {stats.get('total_chunks', 0)}")
print(f"   📊 Total words: {stats.get('total_words', 0):,}")

# Show source breakdown
source_breakdown = stats.get('source_breakdown', {})
if source_breakdown:
    print(f"\n📁 Source breakdown:")
    for source_type, info in source_breakdown.items():
        count = info.get('successful', 0) if isinstance(info, dict) else info
        print(f"   {source_type}: {count} documents")

# Save knowledge base
kb.save_to_file(config.cache_file)
print(f"\n💾 Knowledge base saved to: {config.cache_file}")

# Store for next cell
globals()['knowledge_base'] = kb

# %%
# =============================================================================
# CELL 5: Test Literature-Aware Chat (IF YOU HAVE API KEY)
# =============================================================================

print("\n🤖 TESTING LITERATURE-AWARE CHAT")
print("=" * 40)

try:
    config.validate_api_keys()
    
    from src.chat import LiteratureAssistant
    
    # Create literature assistant
    assistant = LiteratureAssistant(
        knowledge_base=kb,
        anthropic_api_key=config.anthropic_api_key,
        chat_config=config.get_chat_config()
    )
    
    print("✅ Literature assistant created!")
    print(f"📊 Knowledge base: {kb.get_statistics().get('total_documents', 0)} documents")
    
    # Simple chat function
    def chat(question, show_sources=True):
        """Simple chat with the literature assistant."""
        print(f"\n🧑‍🔬 Question: {question}")
        print("🤖 Assistant: ", end="", flush=True)
        
        try:
            response = assistant.ask(question)
            print(response.content)
            
            if show_sources and response.sources_used:
                print(f"\n📚 Sources: {', '.join(response.sources_used)}")
            
        except Exception as e:
            print(f"Error: {e}")
        
        print("\n" + "-" * 50)
    
    print("\n💬 READY FOR CHAT!")
    print("💡 Try these commands:")
    print("   chat('What papers do I have in my knowledge base?')")
    print("   chat('What are the main research topics?')")
    print("   chat('Explain quantum entanglement')")
    
    # Store chat function for easy use
    globals()['chat'] = chat
    globals()['assistant'] = assistant
    
except ValueError as e:
    print("⚠️  Cannot test chat - API key not set")
    print("💡 Set your ANTHROPIC_API_KEY environment variable to test chat")

# =============================================================================
# CELL 6: Summary and Next Steps
# =============================================================================

print("\n🎉 PHYSICS PIPELINE SETUP COMPLETE!")
print("=" * 45)

# Final statistics
bib_count = len(list(config.biblio_folder.glob("*.bib")))
lit_count = len(list(config.literature_folder.iterdir())) if config.literature_folder.exists() else 0
work_count = len(list(config.your_work_folder.iterdir())) if config.your_work_folder.exists() else 0

print(f"📊 FINAL STATUS:")
print(f"   📚 .bib files: {bib_count}")
print(f"   📄 Downloaded papers: {lit_count}")
print(f"   📝 Your papers: {work_count}")
print(f"   🧠 Knowledge base: {'✅ Built' if 'knowledge_base' in globals() else '❌ Not built'}")
print(f"   🤖 Chat ready: {'✅ Yes' if 'chat' in globals() else '❌ Need API key'}")

print(f"\n🚀 WHAT YOU CAN DO NOW:")
if 'chat' in globals():
    print("   • chat('your question here') - Ask the AI assistant")
    print("   • assistant.synthesize_literature('topic') - Get research synthesis")
    print("   • assistant.help_with_writing('task') - Get writing help")
else:
    print("   • Add .bib files and run cells above")
    print("   • Set ANTHROPIC_API_KEY for chat functionality")

print(f"\n📁 KEY LOCATIONS:")
print(f"   📚 Add .bib files: {config.biblio_folder}")
print(f"   📝 Add your papers: {config.your_work_folder}")
print(f"   📄 Downloaded papers: {config.literature_folder}")
print(f"   💾 Knowledge base cache: {config.cache_file}")

print("\n🎯 Your physics literature synthesis pipeline is ready! 🔬📚")

# %%
# Test 1: Overview of your collection
chat("What papers do I have in my knowledge base?")

# %%
chat("Do you know what measurement-induced entanglement phase transitions are?")
