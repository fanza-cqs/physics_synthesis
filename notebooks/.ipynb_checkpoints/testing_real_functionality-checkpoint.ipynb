# %%
# =============================================================================
# CELL 1: Setup and Directory Structure
# =============================================================================

import sys
from pathlib import Path

# Setup paths
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Configuration helper
def create_config(overrides=None):
    from config import PipelineConfig
    config = PipelineConfig(overrides)
    config.project_root = project_root
    config.documents_root = project_root / "documents"
    config.literature_folder = config.documents_root / "literature"
    config.your_work_folder = config.documents_root / "your_work"
    config.biblio_folder = config.documents_root / "biblio"
    config.current_drafts_folder = config.documents_root / "current_drafts"
    config.cache_file = project_root / "physics_knowledge_base.pkl"
    config._create_directories()
    return config

# Create configuration and directories
config = create_config()

print("📁 YOUR PHYSICS PIPELINE DIRECTORY STRUCTURE")
print("=" * 60)
print(f"Project Root: {project_root}")
print()

# Show where to put files
folders = {
    "biblio": "Put your Zotero .bib files here",
    "literature": "Downloaded papers go here (auto-created)",
    "your_work": "Your own published papers",
    "current_drafts": "Your current drafts"
}

for folder_name, description in folders.items():
    folder_path = config.documents_root / folder_name
    exists = "✅" if folder_path.exists() else "❌"
    file_count = len(list(folder_path.iterdir())) if folder_path.exists() else 0
    
    print(f"{exists} {folder_name}/ - {description}")
    print(f"   📍 Location: {folder_path}")
    print(f"   📊 Current files: {file_count}")
    print()

print("🎯 TO GET STARTED:")
print("1. Export .bib files from Zotero → Save to documents/biblio/")
print("2. Copy your papers → Save to documents/your_work/")
print("3. Run the commands below!")
# Out:
# 📁 YOUR PHYSICS PIPELINE DIRECTORY STRUCTURE
# ============================================================
# Project Root: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis
#
# ✅ biblio/ - Put your Zotero .bib files here
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio
#    📊 Current files: 1
#
# ✅ literature/ - Downloaded papers go here (auto-created)
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
#    📊 Current files: 1
#
# ✅ your_work/ - Your own published papers
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/your_work
#    📊 Current files: 10
#
# ✅ current_drafts/ - Your current drafts
#    📍 Location: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/current_drafts
#    📊 Current files: 2
#
# 🎯 TO GET STARTED:
# 1. Export .bib files from Zotero → Save to documents/biblio/
# 2. Copy your papers → Save to documents/your_work/
# 3. Run the commands below!

# %%
# =============================================================================
# CELL 2: Check for Existing .bib Files
# =============================================================================

# Check what .bib files you already have
biblio_folder = config.biblio_folder
bib_files = list(biblio_folder.glob("*.bib"))

print("📚 CHECKING FOR EXISTING .BIB FILES")
print("=" * 40)

if bib_files:
    print(f"✅ Found {len(bib_files)} .bib file(s):")
    for bib_file in bib_files:
        file_size = bib_file.stat().st_size / 1024  # KB
        print(f"   📄 {bib_file.name} ({file_size:.1f} KB)")
    
    # Quick preview of first .bib file
    first_bib = bib_files[0]
    try:
        content = first_bib.read_text()
        lines = content.split('\n')[:10]
        print(f"\n📖 Preview of {first_bib.name}:")
        for line in lines:
            if line.strip():
                print(f"   {line[:60]}...")
                break
    except Exception as e:
        print(f"   Could not preview file: {e}")
        
    print(f"\n🚀 Ready to download literature!")
    
else:
    print("📭 No .bib files found")
    print("\n💡 TO ADD .BIB FILES:")
    print("1. Open Zotero")
    print("2. Select your collection")  
    print("3. Right-click → Export Collection")
    print("4. Choose 'BibTeX' format")
    print(f"5. Save to: {biblio_folder}")
# Out:
# 📚 CHECKING FOR EXISTING .BIB FILES
# ========================================
# 📭 No .bib files found
#
# 💡 TO ADD .BIB FILES:
# 1. Open Zotero
# 2. Select your collection
# 3. Right-click → Export Collection
# 4. Choose 'BibTeX' format
# 5. Save to: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio

# %%
# =============================================================================
# CELL 3: Download Literature from .bib Files (Enhanced with Debug Mode)
# =============================================================================

# Only run this if you have .bib files
bib_files = list(config.biblio_folder.glob("*.bib"))

if bib_files:
    print("🚀 DOWNLOADING LITERATURE FROM ARXIV")
    print("=" * 45)
    
    from src.downloaders import LiteratureDownloader
    
    # Use the first .bib file (or modify to use a specific one)
    bib_file = bib_files[0]
    print(f"📖 Using: {bib_file.name}")
    
    # Initialize enhanced downloader
    downloader = LiteratureDownloader(
        output_directory=config.literature_folder,
        delay_between_downloads=config.download_delay,
        arxiv_config=config.get_arxiv_config()
    )
    
    print("⏳ Starting download... (this may take several minutes)")
    print("💡 The system will:")
    print("   1. Parse your .bib file")
    print("   2. Search for papers on arXiv")
    print("   3. Download PDFs and TEX files")
    print("   4. Generate a detailed report")
    print()
    
    # Download papers with enhanced debugging
    results = downloader.download_from_bibtex(
        bib_file, 
        generate_report=True, 
        debug_mode=True  # Enhanced: Shows detailed debug output
    )
    
    print(f"\n✅ DOWNLOAD COMPLETE!")
    print(f"   📥 Successfully downloaded: {len(results['successful'])}")
    print(f"   ❌ Not found: {len(results['failed'])}")
    
    if results['successful']:
        print(f"\n📄 Sample downloads:")
        for i, result in enumerate(results['successful'][:3]):
            paper = result.paper_metadata
            print(f"   {i+1}. {paper.title[:50]}...")
            print(f"      arXiv: {result.search_result.arxiv_id}")
    
    # Enhanced: Show failed papers with suggestions
    if results['failed']:
        print(f"\n❌ Failed downloads ({len(results['failed'])}):")
        for i, result in enumerate(results['failed'][:3]):
            paper = result.paper_metadata
            print(f"   {i+1}. {paper.title[:50]}...")
            print(f"      Reason: {result.search_result.error_message}")
        
        print(f"\n💡 To debug specific failures, run:")
        print(f"   downloader.analyze_failed_paper('Paper Title Here')")
            
else:
    print("⏭️ SKIPPING DOWNLOAD - No .bib files found")
    print("Add .bib files to documents/biblio/ first!")
# Out:
# 🚀 DOWNLOADING LITERATURE FROM ARXIV
# =============================================
# 📖 Using: DynamicsConditionalEnsembles_small.bib
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.bibtex_parser - INFO - BibTeX parser initialized
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - ArXiv searcher initialized
# 📁 Literature downloader initialized
#    Output directory: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
#    Delay between downloads: 1.2s
#    ArXiv config: {'delay': 1.2, 'max_retries': 3, 'timeout': 30, 'title_threshold': 0.6, 'abstract_threshold': 0.5, 'high_confidence_threshold': 0.9, 'google_api_key': '***HIDDEN***', 'google_search_engine_id': '6070be8a5a9764d74'}
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.literature_downloader - INFO - Literature downloader initialized with output: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
# ⏳ Starting download... (this may take several minutes)
# 💡 The system will:
#    1. Parse your .bib file
#    2. Search for papers on arXiv
#    3. Download PDFs and TEX files
#    4. Generate a detailed report
#
#
# ====================================================================================================
# 🚀 STARTING LITERATURE DOWNLOAD PROCESS
# ====================================================================================================
# 📖 BibTeX file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# 📁 Output directory: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature
# 📊 Generate report: True
# 🐛 Debug mode: True
# ====================================================================================================
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.literature_downloader - INFO - Starting download process from /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
#
# 📖 PARSING BIBTEX FILE...
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.bibtex_parser - INFO - Parsing BibTeX file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.bibtex_parser - INFO - Successfully parsed 33 papers from /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/biblio/DynamicsConditionalEnsembles_small.bib
# ✅ Found 33 papers to process
#
# 📋 PAPER SUMMARY:
#     1. Tight Bounds on the Convergence of Noisy Random Circuits to the Unifor...
#        📝 Abstract: 1516 chars
#        👥 Authors: Abhinav Deshpande, Pradeep Niroula and 4 more
#
#     2. Critical Properties of the Measurement-Induced Transition in Random Qu...
#        📝 Abstract: 1069 chars
#        👥 Authors: Aidan Zabalo, Zabalo, Aidan and 11 more
#
#     3. Exponential Shortcut to Measurement-Induced Entanglement Phase Transit...
#        📝 Abstract: 810 chars
#        👥 Authors: Ali G. Moghaddam, Kim Poyhonen and 1 more
#
#     4. Quantum T-Designs: T-Wise Independence in the Quantum World...
#        📝 Abstract: 486 chars
#        👥 Authors: Andris Ambainis, Ambainis, Andris and 2 more
#
#     5. No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivati...
#        📝 Abstract: 816 chars
#        👥 Authors: Angelo Bassi, Bassi, Angelo and 2 more
#
#     6. Entanglement Transitions and Quantum Bifurcations under Continuous Lon...
#        📝 Abstract: 906 chars
#        👥 Authors: Angelo Russomanno, G. Piccitto and 1 more
#
#     7. Conditional Entropy and Data Processing: An Axiomatic Approach Based o...
#        📝 Abstract: 787 chars
#        👥 Authors: Arthur Americo, Americo, Arthur and 4 more
#
#     8. No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivati...
#        📝 Abstract: 816 chars
#        👥 Authors: Bassi, Angelo, Hejazi, Kasra
#
#     9. Numerical Evaluation of Convex-Roof Entanglement Measures with Applica...
#        📝 Abstract: 919 chars
#        👥 Authors: Beat Rothlisberger, Roethlisberger, Beat and 6 more
#
#    10. Postselection-Free Entanglement Dynamics via Spacetime Duality...
#        📋 arXiv ID:  disordered systems and neural networks
#        📝 Abstract: 1134 chars
#        👥 Authors: Matteo Ippoliti, Matteo Ippoliti and 4 more
#
#    11. Entanglement Phase Transitions in Measurement-Only Dynamics...
#        📝 Abstract: 1628 chars
#        👥 Authors: Matteo Ippoliti, Matteo Ippoliti and 10 more
#
#    12. Dynamical Purification and the Emergence of Quantum State Designs From...
#        📝 Abstract: 1883 chars
#        👥 Authors: Matteo Ippoliti, Ippoliti, Matteo and 2 more
#
#    13. Solvable Model of Deep Thermalization with Distinct Design Times...
#        📝 Abstract: 1116 chars
#        👥 Authors: Matteo Ippoliti, Wen Wei Ho
#
#    14. Classicality, the Ensemble Interpretation, and Decoherence: Resolving ...
#        📝 Abstract: 513 chars
#        👥 Authors: Maximilian Schlosshauer, Schlosshauer, Maximilian
#
#    15. Measurement-Induced Transition in Long-Range Interacting Quantum Circu...
#        📝 Abstract: 957 chars
#        👥 Authors: Melvin A. Block, Maxwell Block and 8 more
#
#    16. What Is Quantum Mechanics Trying to Tell Us...
#        📝 Abstract: 785 chars
#        👥 Authors: Mermin, N. David
#
#    17. A Classical Analog for Electronic Degrees of Freedom in Nonadiabatic C...
#        📝 Abstract: 1351 chars
#        👥 Authors: Meyera), Hans-Dieter, Miller, William H.
#
#    18. Probability Distributions Consistent with a Mixed State...
#        📝 Abstract: 359 chars
#        👥 Authors: Michael A. Nielsen, Nielsen, Michael A.
#
#    19. Characterizing Mixing and Measurement in Quantum Mechanics...
#        📝 Abstract: 724 chars
#        👥 Authors: Michael A. Nielsen, Nielsen, Michael A.
#
#    20. Effective Theory for the Measurement-Induced Phase Transition of Dirac...
#        📝 Abstract: 1473 chars
#        👥 Authors: Michael Buchhold, Buchhold, Michael and 6 more
#
#    21. Dynamical Purification Phase Transition Induced by Quantum Measurement...
#        👥 Authors: Gullans, Michael J., Huse, David A.
#
#    22. Universal Behavior beyond Multifractality of Wave-Functions at Measure...
#        📋 arXiv ID:  statistical mechanics
#        📝 Abstract: 710 chars
#        👥 Authors: Piotr Sierant, Sierant, Piotr and 2 more
#
#    23. Einstein-Podolsky-Rosen Steering and Quantum Steering Ellipsoids: Opti...
#        📝 Abstract: 519 chars
#        👥 Authors: R. McCloskey, McCloskey, R. and 4 more
#
#    24. Entanglement Transitions from Restricted Boltzmann Machines...
#        📝 Abstract: 1458 chars
#        👥 Authors: Raimel Medina, Medina, Raimel and 4 more
#
#    25. How Many Bits Does It Take to Track an Open Quantum System...
#        📝 Abstract: 657 chars
#        👥 Authors: Raisa I. Karasik, Karasik, Raisa and 2 more
#
#    26. Tracking an Open Quantum System Using a Finite State Machine: Stabilit...
#        📝 Abstract: 1078 chars
#        👥 Authors: Raisa I. Karasik, Karasik, Raisa and 2 more
#
#    27. Steering Is an Essential Feature of Non-Locality in Quantum Theory...
#        📝 Abstract: 975 chars
#        👥 Authors: Ramanathan, Ravishankar, Goyeneche, Dardo and 8 more
#
#    28. Efficient Quantum Pseudorandomness with Simple Graph States...
#        📝 Abstract: 784 chars
#        👥 Authors: Rawad Mezher, Mezher, Rawad and 9 more
#
#    29. Thermal Equilibrium Distribution in Infinite-Dimensional Hilbert Space...
#        📝 Abstract: 868 chars
#        👥 Authors: Roderich Tumulka, Tumulka, Roderich
#
#    30. Entanglement Transitions from Holographic Random Tensor Networks...
#        📝 Abstract: 1054 chars
#        👥 Authors: Romain Vasseur, Vasseur, Romain and 8 more
#
#    31. Measuring Tr$$ on Single Copies of $$ Using Random Measurements...
#        📝 Abstract: 426 chars
#        👥 Authors: S. J. van Enk, van Enk, S. J. and 2 more
#
#    32. Measurement-Driven Phase Transition within a Volume-Law Entangled Phas...
#        📋 arXiv ID:  quantum physics
#        📝 Abstract: 1483 chars
#        👥 Authors: Sagar Vijay, Vijay, Sagar and 1 more
#
#    33. Universal Probability Distribution for the Wave Function of a Quantum ...
#        📝 Abstract: 1603 chars
#        👥 Authors: Sheldon Goldstein, Goldstein, Sheldon and 8 more
#
#
# 🔄 PROCESSING PAPERS...
# ====================================================================================================
#
# 📄 PAPER 1/33
# 📝 Title: Tight Bounds on the Convergence of Noisy Random Circuits to the Uniform Distribution
# ⏱️  Starting at: 22:02:43
# 🔍 Searching for paper...
#    👥 Authors: Abhinav Deshpande, Pradeep Niroula, Oles Shtanko and 3 more
#    📅 Year: 2022
# 2025-06-02 22:02:43 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Tight Bounds on the Convergence of Noisy Random Ci...
#     📝 Original title: Tight Bounds on the Convergence of Noisy Random Circuits to the Uniform Distribution
#     🧹 Cleaned title: Tight Bounds on the Convergence of Noisy Random Circuits to the Uniform Distribution
#     🔍 Search query: ti:"Tight Bounds on the Convergence of Noisy Random Circuits to the Uniform Distribution"
#     📡 ArXiv API call: ti:"Tight Bounds on the Convergence of Noisy Random Circuits to the Uniform Distribution"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2112.00716 - Tight bounds on the convergence of noisy random circuits to ...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2112.00716 (confidence: 1.000)
# 📥 DOWNLOADING: 2112.00716
#    📄 Title on arXiv: Tight bounds on the convergence of noisy random circuits to the uniform
#   distribution
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:02:44 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2112.00716
# 2025-06-02 22:02:45 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.pdf
# 2025-06-02 22:02:45 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.tex
# 2025-06-02 22:02:45 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2112.00716 in 3.0s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2112.00716.tex
# 📊 Progress: 3.0% (1/33)
# --------------------------------------------------
#
# 📄 PAPER 2/33
# 📝 Title: Critical Properties of the Measurement-Induced Transition in Random Quantum Circuits
# ⏱️  Starting at: 22:02:46
# 🔍 Searching for paper...
#    👥 Authors: Aidan Zabalo, Zabalo, Aidan, Michael J. Gullans and 10 more
#    📅 Year: 2020
#    📖 Journal: Physical Review B
# 2025-06-02 22:02:46 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Critical Properties of the Measurement-Induced Tra...
#     📝 Original title: Critical Properties of the Measurement-Induced Transition in Random Quantum Circuits
#     🧹 Cleaned title: Critical Properties of the Measurement Induced Transition in Random Quantum Circuits
#     🔍 Search query: ti:"Critical Properties of the Measurement Induced Transition in Random Quantum Circuits"
#     📡 ArXiv API call: ti:"Critical Properties of the Measurement Induced Transition in Random Quantum Circuits"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 1911.00008 - Critical properties of the measurement-induced transition in...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 1911.00008 (confidence: 1.000)
# 📥 DOWNLOADING: 1911.00008
#    📄 Title on arXiv: Critical properties of the measurement-induced transition in random
#   quantum circuits
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:02:47 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1911.00008
# 2025-06-02 22:02:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.pdf
# 2025-06-02 22:02:48 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 2025-06-02 22:02:48 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 1911.00008 in 3.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1911.00008.tex
# 📊 Progress: 6.1% (2/33)
# --------------------------------------------------
#
# 📄 PAPER 3/33
# 📝 Title: Exponential Shortcut to Measurement-Induced Entanglement Phase Transitions
# ⏱️  Starting at: 22:02:49
# 🔍 Searching for paper...
#    👥 Authors: Ali G. Moghaddam, Kim Poyhonen, Teemu Ojanen
#    📅 Year: 2023
#    📖 Journal: Physical Review Letters
# 2025-06-02 22:02:49 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Exponential Shortcut to Measurement-Induced Entang...
#     📝 Original title: Exponential Shortcut to Measurement-Induced Entanglement Phase Transitions
#     🧹 Cleaned title: Exponential Shortcut to Measurement Induced Entanglement Phase Transitions
#     🔍 Search query: ti:"Exponential Shortcut to Measurement Induced Entanglement Phase Transitions"
#     📡 ArXiv API call: ti:"Exponential Shortcut to Measurement Induced Entanglement Phase Transitions"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2302.14044 - Exponential shortcut to measurement-induced entanglement pha...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2302.14044 (confidence: 1.000)
# 📥 DOWNLOADING: 2302.14044
#    📄 Title on arXiv: Exponential shortcut to measurement-induced entanglement phase
#   transitions
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:02:50 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2302.14044
# 2025-06-02 22:02:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.pdf
# 2025-06-02 22:02:51 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.tex
# 2025-06-02 22:02:51 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2302.14044 in 2.9s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2302.14044.tex
# 📊 Progress: 9.1% (3/33)
# --------------------------------------------------
#
# 📄 PAPER 4/33
# 📝 Title: Quantum T-Designs: T-Wise Independence in the Quantum World
# ⏱️  Starting at: 22:02:52
# 🔍 Searching for paper...
#    👥 Authors: Andris Ambainis, Ambainis, Andris, Joseph Emerson and 1 more
#    📅 Year: 2007
# 2025-06-02 22:02:52 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Quantum T-Designs: T-Wise Independence in the Quan...
#     📝 Original title: Quantum T-Designs: T-Wise Independence in the Quantum World
#     🧹 Cleaned title: Quantum T Designs T Wise Independence in the Quantum World
#     🔍 Search query: ti:"Quantum T Designs T Wise Independence in the Quantum World"
#     📡 ArXiv API call: ti:"Quantum T Designs T Wise Independence in the Quantum World"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Title search failed: No matching papers found by title
# 📝 Strategy 3: Searching by abstract content...
#     Abstract preview: A t-design for quantum states is a finite set of quantum states with the property of simulating the ...
#     📝 Abstract snippet: A t design for quantum states is a finite set of quantum sta
#     🔍 Search query: all:"A t design for quantum states is a finite set of quantum sta"
#     📡 ArXiv API call: all:"A t design for quantum states is a finite set of quantum sta"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Abstract search failed: No matching papers found by abstract
# 🌐 Strategy 4: Google Custom Search API fallback...
#
# 🔍 GOOGLE FALLBACK ACTIVATED for: Quantum T-Designs: T-Wise Independence in the Quan...
# 2025-06-02 22:02:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - 🔍 Google Custom Search API activated for: Quantum T-Designs: T-Wise Independence in the Quan...
#     📝 Search query: Quantum T-Designs: T-Wise Independence in the Quantum World
#     📡 Making Google API request...
# 📊 Google returned 5 results
#     📊 Google returned 5 results
#     📄 Result 1: Quantum t-designs: t-wise independence in the quantum world...
#         🔗 URL: https://arxiv.org/abs/quant-ph/0701126
#         📋 Extracted arXiv ID: quant-ph/0701126
#         📄 ArXiv title: Quantum t-designs: t-wise independence in the quantum world...
#         📊 Abstract similarity: 0.965
#         ✅ GOOGLE SEARCH MATCH FOUND!
# ✅ Found via Google API search: quant-ph/0701126 (confidence: 0.600)
# 📥 DOWNLOADING: quant-ph/0701126
#    📄 Title on arXiv: Quantum t-designs: t-wise independence in the quantum world
#    🎯 Confidence: 0.600
#    🔍 Method: google_search
# 2025-06-02 22:02:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: quant-ph/0701126
# 2025-06-02 22:02:55 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0701126.pdf
# 2025-06-02 22:02:55 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0701126.tar.gz: invalid header
#    ✅ Download completed!
#       📄 PDF: Downloaded
# ✅ SUCCESS: Downloaded quant-ph/0701126 in 4.8s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0701126.pdf
# 📊 Progress: 12.1% (4/33)
# --------------------------------------------------
#
# 📄 PAPER 5/33
# 📝 Title: No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivation
# ⏱️  Starting at: 22:02:57
# 🔍 Searching for paper...
#    👥 Authors: Angelo Bassi, Bassi, Angelo, Kasra Hejazi and 1 more
#    📅 Year: 2015
#    📖 Journal: European Journal of Physics
# 2025-06-02 22:02:57 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: No-Faster-than-Light-Signaling Implies Linear Evol...
#     📝 Original title: No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivation
#     🧹 Cleaned title: No Faster than Light Signaling Implies Linear Evolution A Re Derivation
#     🔍 Search query: ti:"No Faster than Light Signaling Implies Linear Evolution A Re Derivation"
#     📡 ArXiv API call: ti:"No Faster than Light Signaling Implies Linear Evolution A Re Derivation"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 1411.1768 - No-faster-than-light-signaling implies linear evolutions. A
# ...
#         📊 Title similarity: 0.833
#         🔍 Medium confidence, checking abstract...
#         📊 Abstract similarity: 0.967
#         ✅ VALIDATED WITH ABSTRACT!
# ✅ Found via title search: 1411.1768 (confidence: 0.833)
# 📥 DOWNLOADING: 1411.1768
#    📄 Title on arXiv: No-faster-than-light-signaling implies linear evolutions. A
#   re-derivation
#    🎯 Confidence: 0.833
#    🔍 Method: title_with_abstract_validation
# 2025-06-02 22:02:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1411.1768
# 2025-06-02 22:02:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
# 2025-06-02 22:02:58 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 22:02:58 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 1411.1768 in 3.0s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 📊 Progress: 15.2% (5/33)
# --------------------------------------------------
#
# 📄 PAPER 6/33
# 📝 Title: Entanglement Transitions and Quantum Bifurcations under Continuous Long-Range Monitoring
# ⏱️  Starting at: 22:03:00
# 🔍 Searching for paper...
#    👥 Authors: Angelo Russomanno, G. Piccitto, Davide Rossini
#    📅 Year: 2023
# 2025-06-02 22:03:00 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Transitions and Quantum Bifurcations ...
#     📝 Original title: Entanglement Transitions and Quantum Bifurcations under Continuous Long-Range Monitoring
#     🧹 Cleaned title: Entanglement Transitions and Quantum Bifurcations under Continuous Long Range Monitoring
#     🔍 Search query: ti:"Entanglement Transitions and Quantum Bifurcations under Continuous Long Range Monitoring"
#     📡 ArXiv API call: ti:"Entanglement Transitions and Quantum Bifurcations under Continuous Long Range Monitoring"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2307.05685 - Entanglement transitions and quantum bifurcations under cont...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2307.05685 (confidence: 1.000)
# 📥 DOWNLOADING: 2307.05685
#    📄 Title on arXiv: Entanglement transitions and quantum bifurcations under continuous
#   long-range monitoring
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:01 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2307.05685
# 2025-06-02 22:03:01 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.pdf
# 2025-06-02 22:03:01 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.tex
# 2025-06-02 22:03:01 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2307.05685 in 3.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2307.05685.tex
# 📊 Progress: 18.2% (6/33)
# --------------------------------------------------
#
# 📄 PAPER 7/33
# 📝 Title: Conditional Entropy and Data Processing: An Axiomatic Approach Based on Core-Concavity
# ⏱️  Starting at: 22:03:03
# 🔍 Searching for paper...
#    👥 Authors: Arthur Americo, Americo, Arthur, M. H. R. Khouzani and 3 more
#    📅 Year: 2020
#    📖 Journal: IEEE Transactions on Information Theory
# 2025-06-02 22:03:03 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Conditional Entropy and Data Processing: An Axioma...
#     📝 Original title: Conditional Entropy and Data Processing: An Axiomatic Approach Based on Core-Concavity
#     🧹 Cleaned title: Conditional Entropy and Data Processing An Axiomatic Approach Based on Core Concavity
#     🔍 Search query: ti:"Conditional Entropy and Data Processing An Axiomatic Approach Based on Core Concavity"
#     📡 ArXiv API call: ti:"Conditional Entropy and Data Processing An Axiomatic Approach Based on Core Concavity"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Title search failed: No matching papers found by title
# 📝 Strategy 3: Searching by abstract content...
#     Abstract preview: This work presents an axiomatization for entropy based on an extension of concavity called core-conc...
#     📝 Abstract snippet: This work presents an axiomatization for entropy based on an
#     🔍 Search query: all:"This work presents an axiomatization for entropy based on an"
#     📡 ArXiv API call: all:"This work presents an axiomatization for entropy based on an"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Abstract search failed: No matching papers found by abstract
# 🌐 Strategy 4: Google Custom Search API fallback...
#
# 🔍 GOOGLE FALLBACK ACTIVATED for: Conditional Entropy and Data Processing: An Axioma...
# 2025-06-02 22:03:05 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - 🔍 Google Custom Search API activated for: Conditional Entropy and Data Processing: An Axioma...
#     📝 Search query: Conditional Entropy and Data Processing: An Axiomatic Approach Based on Core-Concavity
#     📡 Making Google API request...
# 📊 Google returned 5 results
#     📊 Google returned 5 results
#     📄 Result 1: An Extension of the Adversarial Threat Model in Quantitative...
#         🔗 URL: http://www.arxiv.org/pdf/2409.04108
#         📋 Extracted arXiv ID: 2409.04108
#         📄 ArXiv title: An Extension of the Adversarial Threat Model in Quantitative...
#         📊 Abstract similarity: 0.162
#         ❌ Abstract validation failed
#     📄 Result 2: A Variational Characterization of H-Mutual Information and i...
#         🔗 URL: https://arxiv.org/pdf/2406.14304
#         📋 Extracted arXiv ID: 2406.14304
#         📄 ArXiv title: A Variational Characterization of $H$-Mutual Information and...
#         📊 Abstract similarity: 0.236
#         ❌ Abstract validation failed
#     📄 Result 3: Several Representations of α-Mutual Information and Interpre...
#         🔗 URL: https://arxiv.org/pdf/2501.10099
#         📋 Extracted arXiv ID: 2501.10099
#         📄 ArXiv title: Several Representations of $α$-Mutual Information and
#   Inte...
#         📊 Abstract similarity: 0.204
#         ❌ Abstract validation failed
#     📄 Result 4: Quantum conditional entropy from information-theoretic princ...
#         🔗 URL: https://arxiv.org/pdf/2110.15330
#         📋 Extracted arXiv ID: 2110.15330
#         📄 ArXiv title: Quantum conditional entropy from information-theoretic princ...
#         📊 Abstract similarity: 0.192
#         ❌ Abstract validation failed
#     📄 Result 5: A Generalization of the Stratonovich's Value of Information ...
#         🔗 URL: https://arxiv.org/pdf/2201.11449
#         📋 Extracted arXiv ID: 2201.11449
#         📄 ArXiv title: A Generalization of the Stratonovich's Value of Information ...
#         📊 Abstract similarity: 0.147
#         ❌ Abstract validation failed
# ❌ Google API search failed: Google search failed to find matching paper
# 💥 ALL SEARCH STRATEGIES FAILED
# ================================================================================
# ❌ SEARCH FAILED
#    🔍 Method attempted: all_methods_failed
#    💬 Error: Not found using any search method
# ❌ FAILED: Not found using any search method
#    🔍 Search method: all_methods_failed
#    ⏱️  Time spent: 4.3s
# 📊 Progress: 21.2% (7/33)
# --------------------------------------------------
#
# 📄 PAPER 8/33
# 📝 Title: No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivation
# ⏱️  Starting at: 22:03:07
# 🔍 Searching for paper...
#    👥 Authors: Bassi, Angelo, Hejazi, Kasra
#    📅 Year: 2015
#    📖 Journal: European Journal of Physics
# 2025-06-02 22:03:07 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: No-Faster-than-Light-Signaling Implies Linear Evol...
#     📝 Original title: No-Faster-than-Light-Signaling Implies Linear Evolution. A Re-Derivation
#     🧹 Cleaned title: No Faster than Light Signaling Implies Linear Evolution A Re Derivation
#     🔍 Search query: ti:"No Faster than Light Signaling Implies Linear Evolution A Re Derivation"
#     📡 ArXiv API call: ti:"No Faster than Light Signaling Implies Linear Evolution A Re Derivation"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 1411.1768 - No-faster-than-light-signaling implies linear evolutions. A
# ...
#         📊 Title similarity: 0.833
#         🔍 Medium confidence, checking abstract...
#         📊 Abstract similarity: 0.967
#         ✅ VALIDATED WITH ABSTRACT!
# ✅ Found via title search: 1411.1768 (confidence: 0.833)
# 📥 DOWNLOADING: 1411.1768
#    📄 Title on arXiv: No-faster-than-light-signaling implies linear evolutions. A
#   re-derivation
#    🎯 Confidence: 0.833
#    🔍 Method: title_with_abstract_validation
# 2025-06-02 22:03:08 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1411.1768
# 2025-06-02 22:03:09 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
# 2025-06-02 22:03:09 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 2025-06-02 22:03:09 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 1411.1768 in 3.0s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1411.1768.tex
# 📊 Progress: 24.2% (8/33)
# --------------------------------------------------
#
# 📄 PAPER 9/33
# 📝 Title: Numerical Evaluation of Convex-Roof Entanglement Measures with Applications to Spin Rings
# ⏱️  Starting at: 22:03:10
# 🔍 Searching for paper...
#    👥 Authors: Beat Rothlisberger, Roethlisberger, Beat, Rothlisberger, Beat and 5 more
#    📅 Year: 2009
#    📖 Journal: Physical Review A
# 2025-06-02 22:03:10 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Numerical Evaluation of Convex-Roof Entanglement M...
#     📝 Original title: Numerical Evaluation of Convex-Roof Entanglement Measures with Applications to Spin Rings
#     🧹 Cleaned title: Numerical Evaluation of Convex Roof Entanglement Measures with Applications to Spin Rings
#     🔍 Search query: ti:"Numerical Evaluation of Convex Roof Entanglement Measures with Applications to Spin Rings"
#     📡 ArXiv API call: ti:"Numerical Evaluation of Convex Roof Entanglement Measures with Applications to Spin Rings"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 0905.3106 - Numerical evaluation of convex-roof entanglement measures wi...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 0905.3106 (confidence: 1.000)
# 📥 DOWNLOADING: 0905.3106
#    📄 Title on arXiv: Numerical evaluation of convex-roof entanglement measures with
#   applications to spin rings
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:11 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 0905.3106
# 2025-06-02 22:03:12 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.pdf
# 2025-06-02 22:03:12 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.tex
# 2025-06-02 22:03:12 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 0905.3106 in 3.2s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/0905.3106.tex
# 📊 Progress: 27.3% (9/33)
# --------------------------------------------------
#
# 📄 PAPER 10/33
# 📝 Title: Postselection-Free Entanglement Dynamics via Spacetime Duality
# ⏱️  Starting at: 22:03:13
# 🔍 Searching for paper...
#    👥 Authors: Matteo Ippoliti, Matteo Ippoliti, Ippoliti, Matteo and 3 more
#    📅 Year: 2020
#    📖 Journal: arXiv: Disordered Systems and Neural Networks
# 2025-06-02 22:03:13 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Postselection-Free Entanglement Dynamics via Space...
#     📄 Found on arXiv: Nonlinear Systems Identification Using Deep Dynamic Neural N...
#     📊 Abstract similarity: 0.094
# ❌ Failed to validate existing arXiv ID: Failed to validate arXiv ID  disordered systems and neural networks
#     📝 Original title: Postselection-Free Entanglement Dynamics via Spacetime Duality
#     🧹 Cleaned title: Postselection Free Entanglement Dynamics via Spacetime Duality
#     🔍 Search query: ti:"Postselection Free Entanglement Dynamics via Spacetime Duality"
#     📡 ArXiv API call: ti:"Postselection Free Entanglement Dynamics via Spacetime Duality"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2010.15840 - Postselection-free entanglement dynamics via spacetime duali...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2010.15840 (confidence: 1.000)
# 📥 DOWNLOADING: 2010.15840
#    📄 Title on arXiv: Postselection-free entanglement dynamics via spacetime duality
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:15 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2010.15840
# 2025-06-02 22:03:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.pdf
# 2025-06-02 22:03:16 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.tex
# 2025-06-02 22:03:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2010.15840 in 3.8s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2010.15840.tex
# 📊 Progress: 30.3% (10/33)
# --------------------------------------------------
#
# 📄 PAPER 11/33
# 📝 Title: Entanglement Phase Transitions in Measurement-Only Dynamics
# ⏱️  Starting at: 22:03:17
# 🔍 Searching for paper...
#    👥 Authors: Matteo Ippoliti, Matteo Ippoliti, Ippoliti, Matteo and 9 more
#    📅 Year: 2021
#    📖 Journal: Physical Review X
# 2025-06-02 22:03:17 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Phase Transitions in Measurement-Only...
#     📝 Original title: Entanglement Phase Transitions in Measurement-Only Dynamics
#     🧹 Cleaned title: Entanglement Phase Transitions in Measurement Only Dynamics
#     🔍 Search query: ti:"Entanglement Phase Transitions in Measurement Only Dynamics"
#     📡 ArXiv API call: ti:"Entanglement Phase Transitions in Measurement Only Dynamics"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2004.09560 - Entanglement phase transitions in measurement-only dynamics...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2004.09560 (confidence: 1.000)
# 📥 DOWNLOADING: 2004.09560
#    📄 Title on arXiv: Entanglement phase transitions in measurement-only dynamics
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:18 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2004.09560
# 2025-06-02 22:03:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.pdf
# 2025-06-02 22:03:19 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.tex
# 2025-06-02 22:03:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2004.09560 in 3.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.09560.tex
# 📊 Progress: 33.3% (11/33)
# --------------------------------------------------
#
# 📄 PAPER 12/33
# 📝 Title: Dynamical Purification and the Emergence of Quantum State Designs From the Projected Ensemble
# ⏱️  Starting at: 22:03:20
# 🔍 Searching for paper...
#    👥 Authors: Matteo Ippoliti, Ippoliti, Matteo, Wen Wei Ho and 1 more
#    📅 Year: 2022
# 2025-06-02 22:03:20 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Dynamical Purification and the Emergence of Quantu...
#     📝 Original title: Dynamical Purification and the Emergence of Quantum State Designs From the Projected Ensemble
#     🧹 Cleaned title: Dynamical Purification and the Emergence of Quantum State Designs From the Projected Ensemble
#     🔍 Search query: ti:"Dynamical Purification and the Emergence of Quantum State Designs From the Projected Ensemble"
#     📡 ArXiv API call: ti:"Dynamical Purification and the Emergence of Quantum State Designs From the Projected Ensemble"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2204.13657 - Dynamical purification and the emergence of quantum state de...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2204.13657 (confidence: 1.000)
# 📥 DOWNLOADING: 2204.13657
#    📄 Title on arXiv: Dynamical purification and the emergence of quantum state designs from
#   the projected ensemble
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:21 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2204.13657
# 2025-06-02 22:03:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.pdf
# 2025-06-02 22:03:22 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 2025-06-02 22:03:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2204.13657 in 3.4s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2204.13657.tex
# 📊 Progress: 36.4% (12/33)
# --------------------------------------------------
#
# 📄 PAPER 13/33
# 📝 Title: Solvable Model of Deep Thermalization with Distinct Design Times
# ⏱️  Starting at: 22:03:23
# 🔍 Searching for paper...
#    👥 Authors: Matteo Ippoliti, Wen Wei Ho
#    📅 Year: 2022
#    📖 Journal: Quantum
# 2025-06-02 22:03:23 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Solvable Model of Deep Thermalization with Distinc...
#     📝 Original title: Solvable Model of Deep Thermalization with Distinct Design Times
#     🧹 Cleaned title: Solvable Model of Deep Thermalization with Distinct Design Times
#     🔍 Search query: ti:"Solvable Model of Deep Thermalization with Distinct Design Times"
#     📡 ArXiv API call: ti:"Solvable Model of Deep Thermalization with Distinct Design Times"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2208.10542 - Solvable model of deep thermalization with distinct design t...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2208.10542 (confidence: 1.000)
# 📥 DOWNLOADING: 2208.10542
#    📄 Title on arXiv: Solvable model of deep thermalization with distinct design times
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2208.10542
# 2025-06-02 22:03:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.pdf
# 2025-06-02 22:03:25 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.tex
# 2025-06-02 22:03:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2208.10542 in 3.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2208.10542.tex
# 📊 Progress: 39.4% (13/33)
# --------------------------------------------------
#
# 📄 PAPER 14/33
# 📝 Title: Classicality, the Ensemble Interpretation, and Decoherence: Resolving the Hyperion Dispute
# ⏱️  Starting at: 22:03:26
# 🔍 Searching for paper...
#    👥 Authors: Maximilian Schlosshauer, Schlosshauer, Maximilian
#    📅 Year: 2008
#    📖 Journal: Foundations of Physics
# 2025-06-02 22:03:26 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Classicality, the Ensemble Interpretation, and Dec...
#     📝 Original title: Classicality, the Ensemble Interpretation, and Decoherence: Resolving the Hyperion Dispute
#     🧹 Cleaned title: Classicality, the Ensemble Interpretation, and Decoherence Resolving the Hyperion Dispute
#     🔍 Search query: ti:"Classicality, the Ensemble Interpretation, and Decoherence Resolving the Hyperion Dispute"
#     📡 ArXiv API call: ti:"Classicality, the Ensemble Interpretation, and Decoherence Resolving the Hyperion Dispute"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: quant-ph/0605249 - Classicality, the ensemble interpretation, and decoherence: ...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: quant-ph/0605249 (confidence: 1.000)
# 📥 DOWNLOADING: quant-ph/0605249
#    📄 Title on arXiv: Classicality, the ensemble interpretation, and decoherence: Resolving
#   the Hyperion dispute
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: quant-ph/0605249
# 2025-06-02 22:03:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0605249.pdf
# 2025-06-02 22:03:28 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0605249.tar.gz: invalid header
#    ✅ Download completed!
#       📄 PDF: Downloaded
# ✅ SUCCESS: Downloaded quant-ph/0605249 in 3.0s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/quant-ph_0605249.pdf
# 📊 Progress: 42.4% (14/33)
# --------------------------------------------------
#
# 📄 PAPER 15/33
# 📝 Title: Measurement-Induced Transition in Long-Range Interacting Quantum Circuits.
# ⏱️  Starting at: 22:03:29
# 🔍 Searching for paper...
#    👥 Authors: Melvin A. Block, Maxwell Block, Yimu Bao and 7 more
#    📅 Year: 2022
#    📖 Journal: Physical Review Letters
# 2025-06-02 22:03:29 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Induced Transition in Long-Range Inter...
#     📝 Original title: Measurement-Induced Transition in Long-Range Interacting Quantum Circuits.
#     🧹 Cleaned title: Measurement Induced Transition in Long Range Interacting Quantum Circuits
#     🔍 Search query: ti:"Measurement Induced Transition in Long Range Interacting Quantum Circuits"
#     📡 ArXiv API call: ti:"Measurement Induced Transition in Long Range Interacting Quantum Circuits"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2104.13372 - The Measurement-induced Transition in Long-range Interacting...
#         📊 Title similarity: 0.900
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2104.13372 (confidence: 0.900)
# 📥 DOWNLOADING: 2104.13372
#    📄 Title on arXiv: The Measurement-induced Transition in Long-range Interacting Quantum
#   Circuits
#    🎯 Confidence: 0.900
#    🔍 Method: title_high_confidence
# 2025-06-02 22:03:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2104.13372
# 2025-06-02 22:03:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.pdf
# 2025-06-02 22:03:31 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.tex
# 2025-06-02 22:03:31 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2104.13372.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2104.13372 in 3.2s
# ...
# 📊 Progress: 84.8% (28/33)
# --------------------------------------------------
#
# 📄 PAPER 29/33
# 📝 Title: Thermal Equilibrium Distribution in Infinite-Dimensional Hilbert Spaces
# ⏱️  Starting at: 22:04:16
# 🔍 Searching for paper...
#    👥 Authors: Roderich Tumulka, Tumulka, Roderich
#    📅 Year: 2020
#    📖 Journal: Reports on Mathematical Physics
# 2025-06-02 22:04:16 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Thermal Equilibrium Distribution in Infinite-Dimen...
#     📝 Original title: Thermal Equilibrium Distribution in Infinite-Dimensional Hilbert Spaces
#     🧹 Cleaned title: Thermal Equilibrium Distribution in Infinite Dimensional Hilbert Spaces
#     🔍 Search query: ti:"Thermal Equilibrium Distribution in Infinite Dimensional Hilbert Spaces"
#     📡 ArXiv API call: ti:"Thermal Equilibrium Distribution in Infinite Dimensional Hilbert Spaces"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2004.14226 - Thermal Equilibrium Distribution in Infinite-Dimensional Hil...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2004.14226 (confidence: 1.000)
# 📥 DOWNLOADING: 2004.14226
#    📄 Title on arXiv: Thermal Equilibrium Distribution in Infinite-Dimensional Hilbert Spaces
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:04:17 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2004.14226
# 2025-06-02 22:04:18 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.14226.pdf
# 2025-06-02 22:04:18 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.14226.tar.gz: invalid header
#    ✅ Download completed!
#       📄 PDF: Downloaded
# ✅ SUCCESS: Downloaded 2004.14226 in 3.2s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2004.14226.pdf
# 📊 Progress: 87.9% (29/33)
# --------------------------------------------------
#
# 📄 PAPER 30/33
# 📝 Title: Entanglement Transitions from Holographic Random Tensor Networks
# ⏱️  Starting at: 22:04:19
# 🔍 Searching for paper...
#    👥 Authors: Romain Vasseur, Vasseur, Romain, Andrew C. Potter and 7 more
#    📅 Year: 2019
#    📖 Journal: Physical Review B
# 2025-06-02 22:04:19 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Entanglement Transitions from Holographic Random T...
#     📝 Original title: Entanglement Transitions from Holographic Random Tensor Networks
#     🧹 Cleaned title: Entanglement Transitions from Holographic Random Tensor Networks
#     🔍 Search query: ti:"Entanglement Transitions from Holographic Random Tensor Networks"
#     📡 ArXiv API call: ti:"Entanglement Transitions from Holographic Random Tensor Networks"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 1807.07082 - Entanglement Transitions from Holographic Random Tensor Netw...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 1807.07082 (confidence: 1.000)
# 📥 DOWNLOADING: 1807.07082
#    📄 Title on arXiv: Entanglement Transitions from Holographic Random Tensor Networks
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:04:20 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1807.07082
# 2025-06-02 22:04:21 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1807.07082.pdf
# 2025-06-02 22:04:21 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1807.07082.tex
# 2025-06-02 22:04:21 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1807.07082.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 1807.07082 in 3.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1807.07082.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1807.07082.tex
# 📊 Progress: 90.9% (30/33)
# --------------------------------------------------
#
# 📄 PAPER 31/33
# 📝 Title: Measuring Tr$$ on Single Copies of $$ Using Random Measurements
# ⏱️  Starting at: 22:04:22
# 🔍 Searching for paper...
#    👥 Authors: S. J. van Enk, van Enk, S. J., C. W. J. Beenakker and 1 more
#    📅 Year: 2012
#    📖 Journal: Physical Review Letters
# 2025-06-02 22:04:22 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measuring Tr$$ on Single Copies of $$ Using Random...
#     📝 Original title: Measuring Tr$$ on Single Copies of $$ Using Random Measurements
#     🧹 Cleaned title: Measuring Tr$$ on Single Copies of $$ Using Random Measurements
#     🔍 Search query: ti:"Measuring Tr$$ on Single Copies of $$ Using Random Measurements"
#     📡 ArXiv API call: ti:"Measuring Tr$$ on Single Copies of $$ Using Random Measurements"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Title search failed: No matching papers found by title
# 📝 Strategy 3: Searching by abstract content...
#     Abstract preview: While it is known that Tr() can be measured directly (i.e., without first reconstructing the density...
#     📝 Abstract snippet: While it is known that Tr can be measured directly i e witho
#     🔍 Search query: all:"While it is known that Tr can be measured directly i e witho"
#     📡 ArXiv API call: all:"While it is known that Tr can be measured directly i e witho"
#     📊 ArXiv returned 0 entries
#     📊 Found 0 results from arXiv API
# ❌ Abstract search failed: No matching papers found by abstract
# 🌐 Strategy 4: Google Custom Search API fallback...
#
# 🔍 GOOGLE FALLBACK ACTIVATED for: Measuring Tr$$ on Single Copies of $$ Using Random...
# 2025-06-02 22:04:25 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - 🔍 Google Custom Search API activated for: Measuring Tr$$ on Single Copies of $$ Using Random...
#     📝 Search query: Measuring Tr$$ on Single Copies of $$ Using Random Measurements
#     📡 Making Google API request...
# 📊 Google returned 5 results
#     📊 Google returned 5 results
#     📄 Result 1: The power of random measurements: measuring Tr (\rho^ n) on ...
#         🔗 URL: https://arxiv.org/abs/1112.1027
#         📋 Extracted arXiv ID: 1112.1027
#         📄 ArXiv title: The power of random measurements: measuring Tr(ρ^n) on singl...
#         📊 Abstract similarity: 1.000
#         ✅ GOOGLE SEARCH MATCH FOUND!
# ✅ Found via Google API search: 1112.1027 (confidence: 0.600)
# 📥 DOWNLOADING: 1112.1027
#    📄 Title on arXiv: The power of random measurements: measuring Tr(ρ^n) on single copies
#   of ρ
#    🎯 Confidence: 0.600
#    🔍 Method: google_search
# 2025-06-02 22:04:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1112.1027
# 2025-06-02 22:04:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1112.1027.pdf
# 2025-06-02 22:04:27 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1112.1027.tex
# 2025-06-02 22:04:27 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1112.1027.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 1112.1027 in 6.6s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1112.1027.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1112.1027.tex
# 📊 Progress: 93.9% (31/33)
# --------------------------------------------------
#
# 📄 PAPER 32/33
# 📝 Title: Measurement-Driven Phase Transition within a Volume-Law Entangled Phase
# ⏱️  Starting at: 22:04:28
# 🔍 Searching for paper...
#    👥 Authors: Sagar Vijay, Vijay, Sagar, Sagar Vijay
#    📅 Year: 2020
#    📖 Journal: arXiv: Quantum Physics
# 2025-06-02 22:04:28 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Measurement-Driven Phase Transition within a Volum...
#     📄 Found on arXiv: Is Physics Sick? [In Praise of Classical Physics]...
#     📊 Abstract similarity: 0.078
# ❌ Failed to validate existing arXiv ID: Failed to validate arXiv ID  quantum physics
#     📝 Original title: Measurement-Driven Phase Transition within a Volume-Law Entangled Phase
#     🧹 Cleaned title: Measurement Driven Phase Transition within a Volume Law Entangled Phase
#     🔍 Search query: ti:"Measurement Driven Phase Transition within a Volume Law Entangled Phase"
#     📡 ArXiv API call: ti:"Measurement Driven Phase Transition within a Volume Law Entangled Phase"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 2005.03052 - Measurement-Driven Phase Transition within a Volume-Law Enta...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 2005.03052 (confidence: 1.000)
# 📥 DOWNLOADING: 2005.03052
#    📄 Title on arXiv: Measurement-Driven Phase Transition within a Volume-Law Entangled Phase
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:04:33 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 2005.03052
# 2025-06-02 22:04:33 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.03052.pdf
# 2025-06-02 22:04:33 - physics_pipeline.src.utils.file_utils - INFO - Extracted main tex file: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.03052.tex
# 2025-06-02 22:04:33 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - TEX downloaded and extracted: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.03052.tex
#    ✅ Download completed!
#       📄 PDF: Downloaded
#       📝 TEX: Downloaded
# ✅ SUCCESS: Downloaded 2005.03052 in 6.1s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.03052.pdf
#    📝 TEX: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/2005.03052.tex
# 📊 Progress: 97.0% (32/33)
# --------------------------------------------------
#
# 📄 PAPER 33/33
# 📝 Title: Universal Probability Distribution for the Wave Function of a Quantum System Entangled with Its Environment
# ⏱️  Starting at: 22:04:35
# 🔍 Searching for paper...
#    👥 Authors: Sheldon Goldstein, Goldstein, Sheldon, Joel L. Lebowitz and 7 more
#    📅 Year: 2011
#    📖 Journal: Communications in Mathematical Physics
# 2025-06-02 22:04:35 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Searching for paper: Universal Probability Distribution for the Wave Fu...
#     📝 Original title: Universal Probability Distribution for the Wave Function of a Quantum System Entangled with Its Environment
#     🧹 Cleaned title: Universal Probability Distribution for the Wave Function of a Quantum System Entangled with Its Environment
#     🔍 Search query: ti:"Universal Probability Distribution for the Wave Function of a Quantum System Entangled with Its Environment"
#     📡 ArXiv API call: ti:"Universal Probability Distribution for the Wave Function of a Quantum System Entangled with Its Environment"
#     📊 ArXiv returned 1 entries
#     📊 Found 1 results from arXiv API
#     📄 Result 1: 1104.5482 - Universal Probability Distribution for the Wave Function of ...
#         📊 Title similarity: 1.000
#         ✅ HIGH CONFIDENCE MATCH!
# ✅ Found via title search: 1104.5482 (confidence: 1.000)
# 📥 DOWNLOADING: 1104.5482
#    📄 Title on arXiv: Universal Probability Distribution for the Wave Function of a Quantum
#   System Entangled with Its Environment
#    🎯 Confidence: 1.000
#    🔍 Method: title_high_confidence
# 2025-06-02 22:04:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - Downloading paper: 1104.5482
# 2025-06-02 22:04:37 - physics_pipeline.src.downloaders.arxiv_searcher - INFO - PDF downloaded: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1104.5482.pdf
# 2025-06-02 22:04:37 - physics_pipeline.src.utils.file_utils - ERROR - Error extracting tar archive /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1104.5482.tar.gz: invalid header
#    ✅ Download completed!
#       📄 PDF: Downloaded
# ✅ SUCCESS: Downloaded 1104.5482 in 3.8s
#    📄 PDF: /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/1104.5482.pdf
# 📊 Progress: 100.0% (33/33)
# --------------------------------------------------
#
# 📝 GENERATING DOWNLOAD REPORT...
# 📝 Download report saved to /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/download_report.md
# 2025-06-02 22:04:38 - physics_pipeline.src.downloaders.literature_downloader - INFO - Download report saved to /Users/fanza/Desktop/Projects/AcademicAssistantExperiments/physics_synthesis/documents/literature/download_report.md
#
# ====================================================================================================
# 📚 LITERATURE DOWNLOAD SUMMARY
# ====================================================================================================
#
# 📊 OVERALL STATISTICS:
#    Total papers processed: 33
#    Successfully downloaded: 31
#    Failed downloads: 2
#    Success rate: 93.9%
#    Total time: 115.7 seconds
#    Average time per paper: 3.5 seconds
#
# 📄 FILE DOWNLOADS:
#    PDF files: 31
#    TEX files: 24
#
# 🔍 SEARCH METHODS:
#    title_high_confidence: 27 papers
#    google_search: 2 papers
#    title_with_abstract_validation: 2 papers
#
# ✅ SUCCESSFUL DOWNLOADS (showing first 3):
#    1. Tight Bounds on the Convergence of Noisy Random Circuits to ...
#       arXiv: 2112.00716 (confidence: 1.000)
#    2. Critical Properties of the Measurement-Induced Transition in...
#       arXiv: 1911.00008 (confidence: 1.000)
#    3. Exponential Shortcut to Measurement-Induced Entanglement Pha...
#       arXiv: 2302.14044 (confidence: 1.000)
#
# ❌ FAILED DOWNLOADS (showing first 3):
#    1. Conditional Entropy and Data Processing: An Axiomatic Approa...
#       Reason: Not found using any search method
#       Method tried: all_methods_failed
#    2. A Classical Analog for Electronic Degrees of Freedom in Nona...
#       Reason: Not found using any search method
#       Method tried: all_methods_failed
#
# 🌐 API USAGE:
#    ArXiv API calls: 37
#    Google searches: 4
#
# 💡 DEBUGGING SUGGESTIONS:
#    To debug a specific failed paper, use:
#    downloader.analyze_failed_paper('Paper Title Here')
# ====================================================================================================
#
# ✅ DOWNLOAD COMPLETE!
#    📥 Successfully downloaded: 31
#    ❌ Not found: 2
#
# 📄 Sample downloads:
#    1. Tight Bounds on the Convergence of Noisy Random Ci...
#       arXiv: 2112.00716
#    2. Critical Properties of the Measurement-Induced Tra...
#       arXiv: 1911.00008
#    3. Exponential Shortcut to Measurement-Induced Entang...
#       arXiv: 2302.14044
#
# ❌ Failed downloads (2):
#    1. Conditional Entropy and Data Processing: An Axioma...
#       Reason: Not found using any search method
#    2. A Classical Analog for Electronic Degrees of Freed...
#       Reason: Not found using any search method
#
# 💡 To debug specific failures, run:
#    downloader.analyze_failed_paper('Paper Title Here')

# %%
downloader.analyze_failed_paper('Quantum T-Designs: T-Wise Independence in the Quantum World')

# %%
# =============================================================================
# CELL 4: Debug Specific Failed Papers (Add this new cell)
# =============================================================================

# Run this cell to debug specific papers that failed to download
print("🔬 DEBUG SPECIFIC FAILED PAPERS")
print("=" * 40)

# Check if we have any failed papers to debug
try:
    if 'results' in locals() and results['failed']:
        print(f"Found {len(results['failed'])} failed papers")
        
        # Debug the first failed paper
        failed_paper = results['failed'][0]
        paper_title = failed_paper.paper_metadata.title
        
        print(f"\n🧪 Debugging: {paper_title[:60]}...")
        downloader.analyze_failed_paper(paper_title)
        
        # If you want to debug a specific paper from your report, uncomment and modify:
        # specific_paper = "Classicality, the Ensemble Interpretation, and Decoherence: Resolving the Hyperion Dispute"
        # downloader.analyze_failed_paper(specific_paper)
        
    else:
        print("✅ No failed papers to debug (or no download results yet)")
        print("Run the download cell first, or manually debug a specific paper:")
        
        # Example: Debug the paper from your report
        example_paper = "Classicality, the Ensemble Interpretation, and Decoherence: Resolving the Hyperion Dispute"
        print(f"\n🧪 Example: Debugging known failing paper")
        print(f"Title: {example_paper}")
        
        # First check if the expected arXiv ID exists
        expected_id = "quant-ph/0605249"
        print(f"Expected arXiv ID: {expected_id}")
        
        if 'downloader' in locals():
            downloader.check_arxiv_directly(expected_id)
            downloader.analyze_failed_paper(example_paper)
        else:
            print("Run the download cell first to initialize the downloader")
            
except Exception as e:
    print(f"Debug error: {e}")
    print("Make sure you've run the download cell first")

# %%
# =============================================================================
# CELL 5: Manual Paper Testing (Add this new cell)
# =============================================================================

print("🧪 MANUAL PAPER TESTING")
print("=" * 30)

# Test individual papers manually
def test_paper(title, expected_arxiv_id=None):
    """Quick test function for individual papers"""
    if 'downloader' not in locals():
        print("❌ Downloader not initialized. Run the download cell first.")
        return
    
    print(f"\n📝 Testing: {title}")
    if expected_arxiv_id:
        print(f"🎯 Expected ID: {expected_arxiv_id}")
        
        # Check if ID exists directly
        exists = downloader.check_arxiv_directly(expected_arxiv_id)
        if exists:
            print(f"✅ Paper exists on arXiv")
        else:
            print(f"❌ Paper not found with expected ID")
    
    # Test the full search process
    result = downloader.test_single_paper(title, debug_mode=True)
    
    if result.search_result.found:
        print(f"✅ SUCCESS: Found {result.search_result.arxiv_id}")
    else:
        print(f"❌ FAILED: {result.search_result.error_message}")
    
    return result

# Test the papers from your report that failed
failing_papers = [
    ("Classicality, the Ensemble Interpretation, and Decoherence: Resolving the Hyperion Dispute", "quant-ph/0605249"),
    ("Quantum T-Designs: T-Wise Independence in the Quantum World", None),
    ("Dynamical Purification Phase Transition Induced by Quantum Measurements", None)
]

print("Testing papers from your failed download report...")

for title, expected_id in failing_papers:
    try:
        test_paper(title, expected_id)
        print("-" * 50)
    except Exception as e:
        print(f"Error testing {title[:30]}...: {e}")

# %%
# =============================================================================
# CELL 6: Build Knowledge Base (Keep your existing cell)
# =============================================================================

# This remains the same as your existing workflow
print("🧠 BUILDING PHYSICS KNOWLEDGE BASE")
print("=" * 40)

# Continue with knowledge base building as before...
# (Add your existing knowledge base building code here)

# %%
# =============================================================================
# CELL 4: Build Knowledge Base (WITH PYTORCH FIX)
# =============================================================================

# PYTORCH COMPATIBILITY FIX - Add this first!
import torch

if not hasattr(torch, 'get_default_device'):
    def get_default_device():
        """Fallback implementation for older PyTorch versions."""
        if torch.cuda.is_available():
            return torch.device('cuda')
        else:
            return torch.device('cpu')
    
    torch.get_default_device = get_default_device
    print("✅ Applied PyTorch compatibility fix")

# Now the imports should work
print("\n🏗️ BUILDING KNOWLEDGE BASE")
print("=" * 35)

from src.core import KnowledgeBase

# Initialize knowledge base
kb = KnowledgeBase(
    embedding_model=config.embedding_model,
    chunk_size=config.chunk_size,
    chunk_overlap=config.chunk_overlap
)

print("⏳ Building knowledge base from all documents...")
print("💡 This processes:")
print("   📚 Downloaded literature")
print("   📝 Your own papers") 
print("   ✏️  Current drafts")
print("   🧠 Creates semantic embeddings")
print()

# Build knowledge base
stats = kb.build_from_directories(
    literature_folder=config.literature_folder,
    your_work_folder=config.your_work_folder,
    current_drafts_folder=config.current_drafts_folder
)

print("✅ KNOWLEDGE BASE BUILT!")
print(f"   📚 Total documents: {stats.get('total_documents', 0)}")
print(f"   ✅ Successfully processed: {stats.get('successful_documents', 0)}")
print(f"   🧩 Total text chunks: {stats.get('total_chunks', 0)}")
print(f"   📊 Total words: {stats.get('total_words', 0):,}")

# Show source breakdown
source_breakdown = stats.get('source_breakdown', {})
if source_breakdown:
    print(f"\n📁 Source breakdown:")
    for source_type, info in source_breakdown.items():
        count = info.get('successful', 0) if isinstance(info, dict) else info
        print(f"   {source_type}: {count} documents")

# Save knowledge base
kb.save_to_file(config.cache_file)
print(f"\n💾 Knowledge base saved to: {config.cache_file}")

# Store for next cell
globals()['knowledge_base'] = kb

# %%
# =============================================================================
# CELL 5: Test Literature-Aware Chat (IF YOU HAVE API KEY)
# =============================================================================

print("\n🤖 TESTING LITERATURE-AWARE CHAT")
print("=" * 40)

try:
    config.validate_api_keys()
    
    from src.chat import LiteratureAssistant
    
    # Create literature assistant
    assistant = LiteratureAssistant(
        knowledge_base=kb,
        anthropic_api_key=config.anthropic_api_key,
        chat_config=config.get_chat_config()
    )
    
    print("✅ Literature assistant created!")
    print(f"📊 Knowledge base: {kb.get_statistics().get('total_documents', 0)} documents")
    
    # Simple chat function
    def chat(question, show_sources=True):
        """Simple chat with the literature assistant."""
        print(f"\n🧑‍🔬 Question: {question}")
        print("🤖 Assistant: ", end="", flush=True)
        
        try:
            response = assistant.ask(question)
            print(response.content)
            
            if show_sources and response.sources_used:
                print(f"\n📚 Sources: {', '.join(response.sources_used)}")
            
        except Exception as e:
            print(f"Error: {e}")
        
        print("\n" + "-" * 50)
    
    print("\n💬 READY FOR CHAT!")
    print("💡 Try these commands:")
    print("   chat('What papers do I have in my knowledge base?')")
    print("   chat('What are the main research topics?')")
    print("   chat('Explain quantum entanglement')")
    
    # Store chat function for easy use
    globals()['chat'] = chat
    globals()['assistant'] = assistant
    
except ValueError as e:
    print("⚠️  Cannot test chat - API key not set")
    print("💡 Set your ANTHROPIC_API_KEY environment variable to test chat")

# =============================================================================
# CELL 6: Summary and Next Steps
# =============================================================================

print("\n🎉 PHYSICS PIPELINE SETUP COMPLETE!")
print("=" * 45)

# Final statistics
bib_count = len(list(config.biblio_folder.glob("*.bib")))
lit_count = len(list(config.literature_folder.iterdir())) if config.literature_folder.exists() else 0
work_count = len(list(config.your_work_folder.iterdir())) if config.your_work_folder.exists() else 0

print(f"📊 FINAL STATUS:")
print(f"   📚 .bib files: {bib_count}")
print(f"   📄 Downloaded papers: {lit_count}")
print(f"   📝 Your papers: {work_count}")
print(f"   🧠 Knowledge base: {'✅ Built' if 'knowledge_base' in globals() else '❌ Not built'}")
print(f"   🤖 Chat ready: {'✅ Yes' if 'chat' in globals() else '❌ Need API key'}")

print(f"\n🚀 WHAT YOU CAN DO NOW:")
if 'chat' in globals():
    print("   • chat('your question here') - Ask the AI assistant")
    print("   • assistant.synthesize_literature('topic') - Get research synthesis")
    print("   • assistant.help_with_writing('task') - Get writing help")
else:
    print("   • Add .bib files and run cells above")
    print("   • Set ANTHROPIC_API_KEY for chat functionality")

print(f"\n📁 KEY LOCATIONS:")
print(f"   📚 Add .bib files: {config.biblio_folder}")
print(f"   📝 Add your papers: {config.your_work_folder}")
print(f"   📄 Downloaded papers: {config.literature_folder}")
print(f"   💾 Knowledge base cache: {config.cache_file}")

print("\n🎯 Your physics literature synthesis pipeline is ready! 🔬📚")

# %%
# Test 1: Overview of your collection
chat("What papers do I have in my knowledge base?")

# %%
chat("Do you know what measurement-induced entanglement phase transitions are?")
